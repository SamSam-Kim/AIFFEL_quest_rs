# %% [markdown]
# # 프로젝트: ResNet Ablation Study

# %% [markdown]
# ## 0) 라이브러리 버전 확인하기

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds

print(tf.__version__)
print(np.__version__)
# Out:
# 2.10.1
# 1.23.5

# %%
# LMS 버전(2.6.0 / 1.21.4)
# import tensorflow as tf
# import numpy as np
# from tensorflow import keras

# import numpy as np
# import matplotlib.pyplot as plt
# import tensorflow_datasets as tfds

# print(tf.__version__)
# print(np.__version__)
# Out:
# 2.6.0
# 1.21.4

# %% [markdown]
# ## 1) ResNet 기본 블록 구성하기

# %% [markdown]
# 이제 실전으로 돌아와서 ResNet-34와 ResNet-50 네트워크를 직접 만든다고 생각해 봅시다. 우선 ResNet-34와 ResNet-50에서 사용되는 블록의 공통점을 찾고 차이점을 찾아봅시다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 공통점(노란색 표시):
#     - 각 n번째 Conv 블록의 구조 반복 횟수가 각각 3, 4, 6, 3으로 동일하다.
#
# - 차이점(파란색 표시):
#     - ResNet-34: 블록 당 (3 $\times$ 3) Conv Layer 2개로 구성
#     - ResNet-50: 블록 당 (1 $\times$ 1), (3 $\times$ 3), (1 $\times$ 1) 총 3개 Conv Layer로 구성

# %% [markdown]
# ### ResNet 블록 생성 함수

# %%
def build_resnet_block(x, channel=64, block_num=1, bottle_neck=False,
                       stride=1):
    
    # 입력 레이어 x의 identity 저장
    identity = x

    # Conv 레이어: Bottle_neck여부에 따라 3층 혹은 2층
    num_layer = 2 if bottle_neck else 1
    for cnn_num in range(num_layer + 1):
        
        # Conv
        x = keras.layers.Conv2D(
            # Bottle_neck의 경우 마지막층 채널 수 조정
            filters=channel if cnn_num != 2 else channel * 4,
            # Bottle_neck의 경우 처음과 마지막 커널 사이즈 1*1
            kernel_size= 1 if (bottle_neck and cnn_num in [0,2]) else 3,
            # 첫 레이어의 stride는 입력에 따라 조절 (Stage의 첫 레이어)
            strides=1 if cnn_num else stride,
            kernel_initializer='he_normal', padding='same',
            name=f'block{block_num}_conv{cnn_num}')(x)
        
        # Batch Norm
        x = keras.layers.BatchNormalization(
            name=f'block{block_num}_batch_norm{cnn_num}')(x)

        # 마지막 레이어는 Identity Mapping 전 활성화 함수 적용하지 않음
        if cnn_num != num_layer:
            x = keras.layers.Activation('relu')(x)
        
    # Stride 혹은 Channel 수 변경 시 Identity 1x1 Conv 적용
    # stride 및 channel 동기화
    if stride != 1 or x.shape[-1] != channel:
        identity = keras.layers.Conv2D(filters = x.shape[-1], strides=stride,
                                       kernel_size=1, padding='same',
                                       kernel_initializer='he_normal',
                                       name=f'block{block_num}_identity{cnn_num}'
                                      )(identity)
        identity = keras.layers.BatchNormalization(
            name=f'block{block_num}_identity_bn{cnn_num}')(identity)
        
        
    # 마지막엔 identity mapping
    x = keras.layers.add([x, identity], name=f'block{block_num}_add')
    
    # Activation
    x = keras.layers.Activation('relu')(x)

    return x

# %% [markdown]
# ## 2) ResNet-34, ResNet-50 Complete Model

# %% [markdown]
# 블록을 만드는 함수를 사용해서 직접 전체 모델을 만들어 봅시다. ResNet-34와 ResNet-50의 차이에 따라 달라지는 구성(configuration)을 함수에 전달해서 같은 생성 함수 build_resnet()를 통해서 ResNet의 여러 가지 버전들을 모두 만들어 낼 수 있도록 해야 합니다.

# %% [markdown]
# ### ResNet Build 함수

# %%
def build_resnet(input_shape=(32,32,3), num_classes=10, is_50=False):
    
    input_layer = keras.layers.Input(shape=input_shape, name="Input_Layer")
    output = input_layer
    
    # Initial Conv1 (7x7, 64, stride 2)
    output = keras.layers.Conv2D(filters=64, kernel_size=7, strides=2,
                                 kernel_initializer='he_normal', padding='same',
                                 name='Initial_Conv')(output)
    output = keras.layers.BatchNormalization(name='Initial_Conv_BN')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same',
                                       name=f'Initial_Max_Pooling')(output)
    
    # Block 개수 및 채널 순서
    num_blocks_34n50 = [3, 4, 6, 3]
    channel_list = [64, 128, 256, 512]
    
    # is_50 여부에 따라 bottle_nack 옵션을 달리하여 블록을 생성    
    conv_cnt = 0 # 블록 내 기준으로 몇 번째 Conv레이어 인지 표시할 변수
    for i, (num_cnn, channel) in enumerate(zip(num_blocks_34n50, channel_list)):
        for j in range(num_cnn):
            conv_cnt += 1
            output = build_resnet_block(output, channel=channel,
                                        block_num=conv_cnt, bottle_neck=is_50,
                                        # 채널별 가장 첫번째 블록마다 stride 변경
                                        # 단, 첫 채널은 제외
                                        stride=2 if (i and not j) else 1)
    # 마무리 층
    output = keras.layers.AveragePooling2D(pool_size=(1, 1), name='avg_pool')(output)    
    output = keras.layers.Flatten(name='Flatten')(output)
    output = keras.layers.Dense(num_classes, activation='softmax',
                                name=f'fc{num_classes}')(output)

    model = keras.Model(inputs=input_layer, outputs=output,
                        name=f'ResNet{50 if is_50 else 34}')
    
    return model

# %% [markdown]
# - Stride 적용 논리 확인

# %%
num_blocks_34n50 = [3, 4, 6, 3]
channel_list = [64, 128, 256, 512]
 
for i, (num_cnn, channel) in enumerate(zip(num_blocks_34n50, channel_list)):
    for j in range(num_cnn):
        print(i, j+1, channel, 2 if (i and not j) else 1)
# Out:
# 0 1 64 1
# 0 2 64 1
# 0 3 64 1
# 1 1 128 2
# 1 2 128 1
# 1 3 128 1
# 1 4 128 1
# 2 1 256 2
# 2 2 256 1
# 2 3 256 1
# 2 4 256 1
# 2 5 256 1
# 2 6 256 1
# 3 1 512 2
# 3 2 512 1
# 3 3 512 1

# %% [markdown]
# ### Model Summary 확인

# %% [markdown]
# - ResNet34

# %%
resnet_34 = build_resnet(input_shape=(32, 32, 3), is_50=False)
resnet_34.summary()
# Out:
# Model: "ResNet34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_Layer (InputLayer)       [(None, 32, 32, 3)]  0           []
#
#  Initial_Conv (Conv2D)          (None, 16, 16, 64)   9472        ['Input_Layer[0][0]']
#
#  Initial_Conv_BN (BatchNormaliz  (None, 16, 16, 64)  256         ['Initial_Conv[0][0]']
#  ation)
#
#  activation (Activation)        (None, 16, 16, 64)   0           ['Initial_Conv_BN[0][0]']
#
#  Initial_Max_Pooling (MaxPoolin  (None, 8, 8, 64)    0           ['activation[0][0]']
#  g2D)
#
#  block1_conv0 (Conv2D)          (None, 8, 8, 64)     36928       ['Initial_Max_Pooling[0][0]']
#
#  block1_batch_norm0 (BatchNorma  (None, 8, 8, 64)    256         ['block1_conv0[0][0]']
#  lization)
#
#  activation_1 (Activation)      (None, 8, 8, 64)     0           ['block1_batch_norm0[0][0]']
#
#  block1_conv1 (Conv2D)          (None, 8, 8, 64)     36928       ['activation_1[0][0]']
#
#  block1_batch_norm1 (BatchNorma  (None, 8, 8, 64)    256         ['block1_conv1[0][0]']
#  lization)
#
#  block1_add (Add)               (None, 8, 8, 64)     0           ['block1_batch_norm1[0][0]',
#                                                                   'Initial_Max_Pooling[0][0]']
#
#  activation_2 (Activation)      (None, 8, 8, 64)     0           ['block1_add[0][0]']
#
#  block2_conv0 (Conv2D)          (None, 8, 8, 64)     36928       ['activation_2[0][0]']
#
#  block2_batch_norm0 (BatchNorma  (None, 8, 8, 64)    256         ['block2_conv0[0][0]']
#  lization)
#
#  activation_3 (Activation)      (None, 8, 8, 64)     0           ['block2_batch_norm0[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 8, 8, 64)     36928       ['activation_3[0][0]']
#
#  block2_batch_norm1 (BatchNorma  (None, 8, 8, 64)    256         ['block2_conv1[0][0]']
#  lization)
#
#  block2_add (Add)               (None, 8, 8, 64)     0           ['block2_batch_norm1[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 8, 8, 64)     0           ['block2_add[0][0]']
#
#  block3_conv0 (Conv2D)          (None, 8, 8, 64)     36928       ['activation_4[0][0]']
#
#  block3_batch_norm0 (BatchNorma  (None, 8, 8, 64)    256         ['block3_conv0[0][0]']
#  lization)
#
#  activation_5 (Activation)      (None, 8, 8, 64)     0           ['block3_batch_norm0[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 8, 8, 64)     36928       ['activation_5[0][0]']
#
#  block3_batch_norm1 (BatchNorma  (None, 8, 8, 64)    256         ['block3_conv1[0][0]']
#  lization)
#
#  block3_add (Add)               (None, 8, 8, 64)     0           ['block3_batch_norm1[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_6 (Activation)      (None, 8, 8, 64)     0           ['block3_add[0][0]']
#
#  block4_conv0 (Conv2D)          (None, 4, 4, 128)    73856       ['activation_6[0][0]']
#
#  block4_batch_norm0 (BatchNorma  (None, 4, 4, 128)   512         ['block4_conv0[0][0]']
#  lization)
#
#  activation_7 (Activation)      (None, 4, 4, 128)    0           ['block4_batch_norm0[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 4, 4, 128)    147584      ['activation_7[0][0]']
#
#  block4_identity1 (Conv2D)      (None, 4, 4, 128)    8320        ['activation_6[0][0]']
#
#  block4_batch_norm1 (BatchNorma  (None, 4, 4, 128)   512         ['block4_conv1[0][0]']
#  lization)
#
#  block4_identity_bn1 (BatchNorm  (None, 4, 4, 128)   512         ['block4_identity1[0][0]']
#  alization)
#
#  block4_add (Add)               (None, 4, 4, 128)    0           ['block4_batch_norm1[0][0]',
#                                                                   'block4_identity_bn1[0][0]']
#
#  activation_8 (Activation)      (None, 4, 4, 128)    0           ['block4_add[0][0]']
#
#  block5_conv0 (Conv2D)          (None, 4, 4, 128)    147584      ['activation_8[0][0]']
#
#  block5_batch_norm0 (BatchNorma  (None, 4, 4, 128)   512         ['block5_conv0[0][0]']
#  lization)
#
#  activation_9 (Activation)      (None, 4, 4, 128)    0           ['block5_batch_norm0[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 4, 4, 128)    147584      ['activation_9[0][0]']
#
#  block5_batch_norm1 (BatchNorma  (None, 4, 4, 128)   512         ['block5_conv1[0][0]']
#  lization)
#
#  block5_add (Add)               (None, 4, 4, 128)    0           ['block5_batch_norm1[0][0]',
#                                                                   'activation_8[0][0]']
#
#  activation_10 (Activation)     (None, 4, 4, 128)    0           ['block5_add[0][0]']
#
#  block6_conv0 (Conv2D)          (None, 4, 4, 128)    147584      ['activation_10[0][0]']
#
#  block6_batch_norm0 (BatchNorma  (None, 4, 4, 128)   512         ['block6_conv0[0][0]']
#  lization)
#
#  activation_11 (Activation)     (None, 4, 4, 128)    0           ['block6_batch_norm0[0][0]']
#
#  block6_conv1 (Conv2D)          (None, 4, 4, 128)    147584      ['activation_11[0][0]']
#
#  block6_batch_norm1 (BatchNorma  (None, 4, 4, 128)   512         ['block6_conv1[0][0]']
#  lization)
#
#  block6_add (Add)               (None, 4, 4, 128)    0           ['block6_batch_norm1[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 4, 4, 128)    0           ['block6_add[0][0]']
#
#  block7_conv0 (Conv2D)          (None, 4, 4, 128)    147584      ['activation_12[0][0]']
#
#  block7_batch_norm0 (BatchNorma  (None, 4, 4, 128)   512         ['block7_conv0[0][0]']
#  lization)
#
#  activation_13 (Activation)     (None, 4, 4, 128)    0           ['block7_batch_norm0[0][0]']
#
#  block7_conv1 (Conv2D)          (None, 4, 4, 128)    147584      ['activation_13[0][0]']
#
#  block7_batch_norm1 (BatchNorma  (None, 4, 4, 128)   512         ['block7_conv1[0][0]']
#  lization)
#
#  block7_add (Add)               (None, 4, 4, 128)    0           ['block7_batch_norm1[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_14 (Activation)     (None, 4, 4, 128)    0           ['block7_add[0][0]']
#
#  block8_conv0 (Conv2D)          (None, 2, 2, 256)    295168      ['activation_14[0][0]']
#
#  block8_batch_norm0 (BatchNorma  (None, 2, 2, 256)   1024        ['block8_conv0[0][0]']
#  lization)
#
#  activation_15 (Activation)     (None, 2, 2, 256)    0           ['block8_batch_norm0[0][0]']
#
#  block8_conv1 (Conv2D)          (None, 2, 2, 256)    590080      ['activation_15[0][0]']
#
#  block8_identity1 (Conv2D)      (None, 2, 2, 256)    33024       ['activation_14[0][0]']
#
#  block8_batch_norm1 (BatchNorma  (None, 2, 2, 256)   1024        ['block8_conv1[0][0]']
#  lization)
#
#  block8_identity_bn1 (BatchNorm  (None, 2, 2, 256)   1024        ['block8_identity1[0][0]']
#  alization)
#
#  block8_add (Add)               (None, 2, 2, 256)    0           ['block8_batch_norm1[0][0]',
#                                                                   'block8_identity_bn1[0][0]']
#
#  activation_16 (Activation)     (None, 2, 2, 256)    0           ['block8_add[0][0]']
#
#  block9_conv0 (Conv2D)          (None, 2, 2, 256)    590080      ['activation_16[0][0]']
#
#  block9_batch_norm0 (BatchNorma  (None, 2, 2, 256)   1024        ['block9_conv0[0][0]']
#  lization)
#
#  activation_17 (Activation)     (None, 2, 2, 256)    0           ['block9_batch_norm0[0][0]']
#
#  block9_conv1 (Conv2D)          (None, 2, 2, 256)    590080      ['activation_17[0][0]']
#
#  block9_batch_norm1 (BatchNorma  (None, 2, 2, 256)   1024        ['block9_conv1[0][0]']
#  lization)
#
#  block9_add (Add)               (None, 2, 2, 256)    0           ['block9_batch_norm1[0][0]',
#                                                                   'activation_16[0][0]']
#
#  activation_18 (Activation)     (None, 2, 2, 256)    0           ['block9_add[0][0]']
#
#  block10_conv0 (Conv2D)         (None, 2, 2, 256)    590080      ['activation_18[0][0]']
#
#  block10_batch_norm0 (BatchNorm  (None, 2, 2, 256)   1024        ['block10_conv0[0][0]']
#  alization)
#
#  activation_19 (Activation)     (None, 2, 2, 256)    0           ['block10_batch_norm0[0][0]']
#
#  block10_conv1 (Conv2D)         (None, 2, 2, 256)    590080      ['activation_19[0][0]']
#
#  block10_batch_norm1 (BatchNorm  (None, 2, 2, 256)   1024        ['block10_conv1[0][0]']
#  alization)
#
#  block10_add (Add)              (None, 2, 2, 256)    0           ['block10_batch_norm1[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_20 (Activation)     (None, 2, 2, 256)    0           ['block10_add[0][0]']
#
#  block11_conv0 (Conv2D)         (None, 2, 2, 256)    590080      ['activation_20[0][0]']
#
#  block11_batch_norm0 (BatchNorm  (None, 2, 2, 256)   1024        ['block11_conv0[0][0]']
#  alization)
#
#  activation_21 (Activation)     (None, 2, 2, 256)    0           ['block11_batch_norm0[0][0]']
#
#  block11_conv1 (Conv2D)         (None, 2, 2, 256)    590080      ['activation_21[0][0]']
#
#  block11_batch_norm1 (BatchNorm  (None, 2, 2, 256)   1024        ['block11_conv1[0][0]']
#  alization)
#
#  block11_add (Add)              (None, 2, 2, 256)    0           ['block11_batch_norm1[0][0]',
#                                                                   'activation_20[0][0]']
#
#  activation_22 (Activation)     (None, 2, 2, 256)    0           ['block11_add[0][0]']
#
#  block12_conv0 (Conv2D)         (None, 2, 2, 256)    590080      ['activation_22[0][0]']
#
#  block12_batch_norm0 (BatchNorm  (None, 2, 2, 256)   1024        ['block12_conv0[0][0]']
#  alization)
#
#  activation_23 (Activation)     (None, 2, 2, 256)    0           ['block12_batch_norm0[0][0]']
#
#  block12_conv1 (Conv2D)         (None, 2, 2, 256)    590080      ['activation_23[0][0]']
#
#  block12_batch_norm1 (BatchNorm  (None, 2, 2, 256)   1024        ['block12_conv1[0][0]']
#  alization)
#
#  block12_add (Add)              (None, 2, 2, 256)    0           ['block12_batch_norm1[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_24 (Activation)     (None, 2, 2, 256)    0           ['block12_add[0][0]']
#
#  block13_conv0 (Conv2D)         (None, 2, 2, 256)    590080      ['activation_24[0][0]']
#
#  block13_batch_norm0 (BatchNorm  (None, 2, 2, 256)   1024        ['block13_conv0[0][0]']
#  alization)
#
#  activation_25 (Activation)     (None, 2, 2, 256)    0           ['block13_batch_norm0[0][0]']
#
#  block13_conv1 (Conv2D)         (None, 2, 2, 256)    590080      ['activation_25[0][0]']
#
#  block13_batch_norm1 (BatchNorm  (None, 2, 2, 256)   1024        ['block13_conv1[0][0]']
#  alization)
#
#  block13_add (Add)              (None, 2, 2, 256)    0           ['block13_batch_norm1[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_26 (Activation)     (None, 2, 2, 256)    0           ['block13_add[0][0]']
#
#  block14_conv0 (Conv2D)         (None, 1, 1, 512)    1180160     ['activation_26[0][0]']
#
#  block14_batch_norm0 (BatchNorm  (None, 1, 1, 512)   2048        ['block14_conv0[0][0]']
#  alization)
#
#  activation_27 (Activation)     (None, 1, 1, 512)    0           ['block14_batch_norm0[0][0]']
#
#  block14_conv1 (Conv2D)         (None, 1, 1, 512)    2359808     ['activation_27[0][0]']
#
#  block14_identity1 (Conv2D)     (None, 1, 1, 512)    131584      ['activation_26[0][0]']
#
#  block14_batch_norm1 (BatchNorm  (None, 1, 1, 512)   2048        ['block14_conv1[0][0]']
#  alization)
#
#  block14_identity_bn1 (BatchNor  (None, 1, 1, 512)   2048        ['block14_identity1[0][0]']
#  malization)
#
#  block14_add (Add)              (None, 1, 1, 512)    0           ['block14_batch_norm1[0][0]',
#                                                                   'block14_identity_bn1[0][0]']
#
#  activation_28 (Activation)     (None, 1, 1, 512)    0           ['block14_add[0][0]']
#
#  block15_conv0 (Conv2D)         (None, 1, 1, 512)    2359808     ['activation_28[0][0]']
#
#  block15_batch_norm0 (BatchNorm  (None, 1, 1, 512)   2048        ['block15_conv0[0][0]']
#  alization)
#
#  activation_29 (Activation)     (None, 1, 1, 512)    0           ['block15_batch_norm0[0][0]']
#
#  block15_conv1 (Conv2D)         (None, 1, 1, 512)    2359808     ['activation_29[0][0]']
#
#  block15_batch_norm1 (BatchNorm  (None, 1, 1, 512)   2048        ['block15_conv1[0][0]']
#  alization)
#
#  block15_add (Add)              (None, 1, 1, 512)    0           ['block15_batch_norm1[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_30 (Activation)     (None, 1, 1, 512)    0           ['block15_add[0][0]']
#
#  block16_conv0 (Conv2D)         (None, 1, 1, 512)    2359808     ['activation_30[0][0]']
#
#  block16_batch_norm0 (BatchNorm  (None, 1, 1, 512)   2048        ['block16_conv0[0][0]']
#  alization)
#
#  activation_31 (Activation)     (None, 1, 1, 512)    0           ['block16_batch_norm0[0][0]']
#
#  block16_conv1 (Conv2D)         (None, 1, 1, 512)    2359808     ['activation_31[0][0]']
#
#  block16_batch_norm1 (BatchNorm  (None, 1, 1, 512)   2048        ['block16_conv1[0][0]']
#  alization)
#
#  block16_add (Add)              (None, 1, 1, 512)    0           ['block16_batch_norm1[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_32 (Activation)     (None, 1, 1, 512)    0           ['block16_add[0][0]']
#
#  avg_pool (AveragePooling2D)    (None, 1, 1, 512)    0           ['activation_32[0][0]']
#
#  Flatten (Flatten)              (None, 512)          0           ['avg_pool[0][0]']
#
#  fc10 (Dense)                   (None, 10)           5130        ['Flatten[0][0]']
#
# ==================================================================================================
# Total params: 21,315,338
# Trainable params: 21,298,314
# Non-trainable params: 17,024
# __________________________________________________________________________________________________

# %%
resnet_50 = build_resnet(input_shape=(32, 32, 3), is_50=True)
resnet_50.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_Layer (InputLayer)       [(None, 32, 32, 3)]  0           []
#
#  Initial_Conv (Conv2D)          (None, 16, 16, 64)   9472        ['Input_Layer[0][0]']
#
#  Initial_Conv_BN (BatchNormaliz  (None, 16, 16, 64)  256         ['Initial_Conv[0][0]']
#  ation)
#
#  activation_33 (Activation)     (None, 16, 16, 64)   0           ['Initial_Conv_BN[0][0]']
#
#  Initial_Max_Pooling (MaxPoolin  (None, 8, 8, 64)    0           ['activation_33[0][0]']
#  g2D)
#
#  block1_conv0 (Conv2D)          (None, 8, 8, 64)     4160        ['Initial_Max_Pooling[0][0]']
#
#  block1_batch_norm0 (BatchNorma  (None, 8, 8, 64)    256         ['block1_conv0[0][0]']
#  lization)
#
#  activation_34 (Activation)     (None, 8, 8, 64)     0           ['block1_batch_norm0[0][0]']
#
#  block1_conv1 (Conv2D)          (None, 8, 8, 64)     36928       ['activation_34[0][0]']
#
#  block1_batch_norm1 (BatchNorma  (None, 8, 8, 64)    256         ['block1_conv1[0][0]']
#  lization)
#
#  activation_35 (Activation)     (None, 8, 8, 64)     0           ['block1_batch_norm1[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 8, 8, 256)    16640       ['activation_35[0][0]']
#
#  block1_identity2 (Conv2D)      (None, 8, 8, 256)    16640       ['Initial_Max_Pooling[0][0]']
#
#  block1_batch_norm2 (BatchNorma  (None, 8, 8, 256)   1024        ['block1_conv2[0][0]']
#  lization)
#
#  block1_identity_bn2 (BatchNorm  (None, 8, 8, 256)   1024        ['block1_identity2[0][0]']
#  alization)
#
#  block1_add (Add)               (None, 8, 8, 256)    0           ['block1_batch_norm2[0][0]',
#                                                                   'block1_identity_bn2[0][0]']
#
#  activation_36 (Activation)     (None, 8, 8, 256)    0           ['block1_add[0][0]']
#
#  block2_conv0 (Conv2D)          (None, 8, 8, 64)     16448       ['activation_36[0][0]']
#
#  block2_batch_norm0 (BatchNorma  (None, 8, 8, 64)    256         ['block2_conv0[0][0]']
#  lization)
#
#  activation_37 (Activation)     (None, 8, 8, 64)     0           ['block2_batch_norm0[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 8, 8, 64)     36928       ['activation_37[0][0]']
#
#  block2_batch_norm1 (BatchNorma  (None, 8, 8, 64)    256         ['block2_conv1[0][0]']
#  lization)
#
#  activation_38 (Activation)     (None, 8, 8, 64)     0           ['block2_batch_norm1[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 8, 8, 256)    16640       ['activation_38[0][0]']
#
#  block2_identity2 (Conv2D)      (None, 8, 8, 256)    65792       ['activation_36[0][0]']
#
#  block2_batch_norm2 (BatchNorma  (None, 8, 8, 256)   1024        ['block2_conv2[0][0]']
#  lization)
#
#  block2_identity_bn2 (BatchNorm  (None, 8, 8, 256)   1024        ['block2_identity2[0][0]']
#  alization)
#
#  block2_add (Add)               (None, 8, 8, 256)    0           ['block2_batch_norm2[0][0]',
#                                                                   'block2_identity_bn2[0][0]']
#
#  activation_39 (Activation)     (None, 8, 8, 256)    0           ['block2_add[0][0]']
#
#  block3_conv0 (Conv2D)          (None, 8, 8, 64)     16448       ['activation_39[0][0]']
#
#  block3_batch_norm0 (BatchNorma  (None, 8, 8, 64)    256         ['block3_conv0[0][0]']
#  lization)
#
#  activation_40 (Activation)     (None, 8, 8, 64)     0           ['block3_batch_norm0[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 8, 8, 64)     36928       ['activation_40[0][0]']
#
#  block3_batch_norm1 (BatchNorma  (None, 8, 8, 64)    256         ['block3_conv1[0][0]']
#  lization)
#
#  activation_41 (Activation)     (None, 8, 8, 64)     0           ['block3_batch_norm1[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 8, 8, 256)    16640       ['activation_41[0][0]']
#
#  block3_identity2 (Conv2D)      (None, 8, 8, 256)    65792       ['activation_39[0][0]']
#
#  block3_batch_norm2 (BatchNorma  (None, 8, 8, 256)   1024        ['block3_conv2[0][0]']
#  lization)
#
#  block3_identity_bn2 (BatchNorm  (None, 8, 8, 256)   1024        ['block3_identity2[0][0]']
#  alization)
#
#  block3_add (Add)               (None, 8, 8, 256)    0           ['block3_batch_norm2[0][0]',
#                                                                   'block3_identity_bn2[0][0]']
#
#  activation_42 (Activation)     (None, 8, 8, 256)    0           ['block3_add[0][0]']
#
#  block4_conv0 (Conv2D)          (None, 4, 4, 128)    32896       ['activation_42[0][0]']
#
#  block4_batch_norm0 (BatchNorma  (None, 4, 4, 128)   512         ['block4_conv0[0][0]']
#  lization)
#
#  activation_43 (Activation)     (None, 4, 4, 128)    0           ['block4_batch_norm0[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 4, 4, 128)    147584      ['activation_43[0][0]']
#
#  block4_batch_norm1 (BatchNorma  (None, 4, 4, 128)   512         ['block4_conv1[0][0]']
#  lization)
#
#  activation_44 (Activation)     (None, 4, 4, 128)    0           ['block4_batch_norm1[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 4, 4, 512)    66048       ['activation_44[0][0]']
#
#  block4_identity2 (Conv2D)      (None, 4, 4, 512)    131584      ['activation_42[0][0]']
#
#  block4_batch_norm2 (BatchNorma  (None, 4, 4, 512)   2048        ['block4_conv2[0][0]']
#  lization)
#
#  block4_identity_bn2 (BatchNorm  (None, 4, 4, 512)   2048        ['block4_identity2[0][0]']
#  alization)
#
#  block4_add (Add)               (None, 4, 4, 512)    0           ['block4_batch_norm2[0][0]',
#                                                                   'block4_identity_bn2[0][0]']
#
#  activation_45 (Activation)     (None, 4, 4, 512)    0           ['block4_add[0][0]']
#
#  block5_conv0 (Conv2D)          (None, 4, 4, 128)    65664       ['activation_45[0][0]']
#
#  block5_batch_norm0 (BatchNorma  (None, 4, 4, 128)   512         ['block5_conv0[0][0]']
#  lization)
#
#  activation_46 (Activation)     (None, 4, 4, 128)    0           ['block5_batch_norm0[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 4, 4, 128)    147584      ['activation_46[0][0]']
#
#  block5_batch_norm1 (BatchNorma  (None, 4, 4, 128)   512         ['block5_conv1[0][0]']
#  lization)
#
#  activation_47 (Activation)     (None, 4, 4, 128)    0           ['block5_batch_norm1[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 4, 4, 512)    66048       ['activation_47[0][0]']
#
#  block5_identity2 (Conv2D)      (None, 4, 4, 512)    262656      ['activation_45[0][0]']
#
#  block5_batch_norm2 (BatchNorma  (None, 4, 4, 512)   2048        ['block5_conv2[0][0]']
#  lization)
#
#  block5_identity_bn2 (BatchNorm  (None, 4, 4, 512)   2048        ['block5_identity2[0][0]']
#  alization)
#
#  block5_add (Add)               (None, 4, 4, 512)    0           ['block5_batch_norm2[0][0]',
#                                                                   'block5_identity_bn2[0][0]']
#
#  activation_48 (Activation)     (None, 4, 4, 512)    0           ['block5_add[0][0]']
#
#  block6_conv0 (Conv2D)          (None, 4, 4, 128)    65664       ['activation_48[0][0]']
#
#  block6_batch_norm0 (BatchNorma  (None, 4, 4, 128)   512         ['block6_conv0[0][0]']
#  lization)
#
#  activation_49 (Activation)     (None, 4, 4, 128)    0           ['block6_batch_norm0[0][0]']
#
#  block6_conv1 (Conv2D)          (None, 4, 4, 128)    147584      ['activation_49[0][0]']
#
#  block6_batch_norm1 (BatchNorma  (None, 4, 4, 128)   512         ['block6_conv1[0][0]']
#  lization)
#
#  activation_50 (Activation)     (None, 4, 4, 128)    0           ['block6_batch_norm1[0][0]']
#
#  block6_conv2 (Conv2D)          (None, 4, 4, 512)    66048       ['activation_50[0][0]']
#
#  block6_identity2 (Conv2D)      (None, 4, 4, 512)    262656      ['activation_48[0][0]']
#
#  block6_batch_norm2 (BatchNorma  (None, 4, 4, 512)   2048        ['block6_conv2[0][0]']
#  lization)
#
#  block6_identity_bn2 (BatchNorm  (None, 4, 4, 512)   2048        ['block6_identity2[0][0]']
#  alization)
#
#  block6_add (Add)               (None, 4, 4, 512)    0           ['block6_batch_norm2[0][0]',
#                                                                   'block6_identity_bn2[0][0]']
#
#  activation_51 (Activation)     (None, 4, 4, 512)    0           ['block6_add[0][0]']
#
#  block7_conv0 (Conv2D)          (None, 4, 4, 128)    65664       ['activation_51[0][0]']
#
#  block7_batch_norm0 (BatchNorma  (None, 4, 4, 128)   512         ['block7_conv0[0][0]']
#  lization)
#
#  activation_52 (Activation)     (None, 4, 4, 128)    0           ['block7_batch_norm0[0][0]']
#
#  block7_conv1 (Conv2D)          (None, 4, 4, 128)    147584      ['activation_52[0][0]']
#
#  block7_batch_norm1 (BatchNorma  (None, 4, 4, 128)   512         ['block7_conv1[0][0]']
#  lization)
#
#  activation_53 (Activation)     (None, 4, 4, 128)    0           ['block7_batch_norm1[0][0]']
#
#  block7_conv2 (Conv2D)          (None, 4, 4, 512)    66048       ['activation_53[0][0]']
#
#  block7_identity2 (Conv2D)      (None, 4, 4, 512)    262656      ['activation_51[0][0]']
#
#  block7_batch_norm2 (BatchNorma  (None, 4, 4, 512)   2048        ['block7_conv2[0][0]']
#  lization)
#
#  block7_identity_bn2 (BatchNorm  (None, 4, 4, 512)   2048        ['block7_identity2[0][0]']
#  alization)
#
#  block7_add (Add)               (None, 4, 4, 512)    0           ['block7_batch_norm2[0][0]',
#                                                                   'block7_identity_bn2[0][0]']
#
#  activation_54 (Activation)     (None, 4, 4, 512)    0           ['block7_add[0][0]']
#
#  block8_conv0 (Conv2D)          (None, 2, 2, 256)    131328      ['activation_54[0][0]']
#
#  block8_batch_norm0 (BatchNorma  (None, 2, 2, 256)   1024        ['block8_conv0[0][0]']
#  lization)
#
#  activation_55 (Activation)     (None, 2, 2, 256)    0           ['block8_batch_norm0[0][0]']
#
#  block8_conv1 (Conv2D)          (None, 2, 2, 256)    590080      ['activation_55[0][0]']
#
#  block8_batch_norm1 (BatchNorma  (None, 2, 2, 256)   1024        ['block8_conv1[0][0]']
#  lization)
#
#  activation_56 (Activation)     (None, 2, 2, 256)    0           ['block8_batch_norm1[0][0]']
#
#  block8_conv2 (Conv2D)          (None, 2, 2, 1024)   263168      ['activation_56[0][0]']
#
#  block8_identity2 (Conv2D)      (None, 2, 2, 1024)   525312      ['activation_54[0][0]']
#
#  block8_batch_norm2 (BatchNorma  (None, 2, 2, 1024)  4096        ['block8_conv2[0][0]']
#  lization)
#
#  block8_identity_bn2 (BatchNorm  (None, 2, 2, 1024)  4096        ['block8_identity2[0][0]']
#  alization)
#
#  block8_add (Add)               (None, 2, 2, 1024)   0           ['block8_batch_norm2[0][0]',
#                                                                   'block8_identity_bn2[0][0]']
#
#  activation_57 (Activation)     (None, 2, 2, 1024)   0           ['block8_add[0][0]']
#
#  block9_conv0 (Conv2D)          (None, 2, 2, 256)    262400      ['activation_57[0][0]']
#
#  block9_batch_norm0 (BatchNorma  (None, 2, 2, 256)   1024        ['block9_conv0[0][0]']
#  lization)
#
#  activation_58 (Activation)     (None, 2, 2, 256)    0           ['block9_batch_norm0[0][0]']
#
#  block9_conv1 (Conv2D)          (None, 2, 2, 256)    590080      ['activation_58[0][0]']
#
#  block9_batch_norm1 (BatchNorma  (None, 2, 2, 256)   1024        ['block9_conv1[0][0]']
#  lization)
#
#  activation_59 (Activation)     (None, 2, 2, 256)    0           ['block9_batch_norm1[0][0]']
#
#  block9_conv2 (Conv2D)          (None, 2, 2, 1024)   263168      ['activation_59[0][0]']
#
#  block9_identity2 (Conv2D)      (None, 2, 2, 1024)   1049600     ['activation_57[0][0]']
#
#  block9_batch_norm2 (BatchNorma  (None, 2, 2, 1024)  4096        ['block9_conv2[0][0]']
#  lization)
#
#  block9_identity_bn2 (BatchNorm  (None, 2, 2, 1024)  4096        ['block9_identity2[0][0]']
#  alization)
#
#  block9_add (Add)               (None, 2, 2, 1024)   0           ['block9_batch_norm2[0][0]',
#                                                                   'block9_identity_bn2[0][0]']
#
#  activation_60 (Activation)     (None, 2, 2, 1024)   0           ['block9_add[0][0]']
#
#  block10_conv0 (Conv2D)         (None, 2, 2, 256)    262400      ['activation_60[0][0]']
#
#  block10_batch_norm0 (BatchNorm  (None, 2, 2, 256)   1024        ['block10_conv0[0][0]']
#  alization)
#
#  activation_61 (Activation)     (None, 2, 2, 256)    0           ['block10_batch_norm0[0][0]']
#
#  block10_conv1 (Conv2D)         (None, 2, 2, 256)    590080      ['activation_61[0][0]']
#
#  block10_batch_norm1 (BatchNorm  (None, 2, 2, 256)   1024        ['block10_conv1[0][0]']
#  alization)
#
#  activation_62 (Activation)     (None, 2, 2, 256)    0           ['block10_batch_norm1[0][0]']
#
#  block10_conv2 (Conv2D)         (None, 2, 2, 1024)   263168      ['activation_62[0][0]']
#
#  block10_identity2 (Conv2D)     (None, 2, 2, 1024)   1049600     ['activation_60[0][0]']
#
#  block10_batch_norm2 (BatchNorm  (None, 2, 2, 1024)  4096        ['block10_conv2[0][0]']
#  alization)
#
#  block10_identity_bn2 (BatchNor  (None, 2, 2, 1024)  4096        ['block10_identity2[0][0]']
#  malization)
#
#  block10_add (Add)              (None, 2, 2, 1024)   0           ['block10_batch_norm2[0][0]',
#                                                                   'block10_identity_bn2[0][0]']
#
#  activation_63 (Activation)     (None, 2, 2, 1024)   0           ['block10_add[0][0]']
#
#  block11_conv0 (Conv2D)         (None, 2, 2, 256)    262400      ['activation_63[0][0]']
#
#  block11_batch_norm0 (BatchNorm  (None, 2, 2, 256)   1024        ['block11_conv0[0][0]']
#  alization)
#
#  activation_64 (Activation)     (None, 2, 2, 256)    0           ['block11_batch_norm0[0][0]']
#
#  block11_conv1 (Conv2D)         (None, 2, 2, 256)    590080      ['activation_64[0][0]']
#
#  block11_batch_norm1 (BatchNorm  (None, 2, 2, 256)   1024        ['block11_conv1[0][0]']
#  alization)
#
#  activation_65 (Activation)     (None, 2, 2, 256)    0           ['block11_batch_norm1[0][0]']
#
#  block11_conv2 (Conv2D)         (None, 2, 2, 1024)   263168      ['activation_65[0][0]']
#
#  block11_identity2 (Conv2D)     (None, 2, 2, 1024)   1049600     ['activation_63[0][0]']
#
#  block11_batch_norm2 (BatchNorm  (None, 2, 2, 1024)  4096        ['block11_conv2[0][0]']
#  alization)
#
#  block11_identity_bn2 (BatchNor  (None, 2, 2, 1024)  4096        ['block11_identity2[0][0]']
#  malization)
#
#  block11_add (Add)              (None, 2, 2, 1024)   0           ['block11_batch_norm2[0][0]',
#                                                                   'block11_identity_bn2[0][0]']
#
#  activation_66 (Activation)     (None, 2, 2, 1024)   0           ['block11_add[0][0]']
#
#  block12_conv0 (Conv2D)         (None, 2, 2, 256)    262400      ['activation_66[0][0]']
#
#  block12_batch_norm0 (BatchNorm  (None, 2, 2, 256)   1024        ['block12_conv0[0][0]']
#  alization)
#
#  activation_67 (Activation)     (None, 2, 2, 256)    0           ['block12_batch_norm0[0][0]']
#
#  block12_conv1 (Conv2D)         (None, 2, 2, 256)    590080      ['activation_67[0][0]']
#
#  block12_batch_norm1 (BatchNorm  (None, 2, 2, 256)   1024        ['block12_conv1[0][0]']
#  alization)
#
#  activation_68 (Activation)     (None, 2, 2, 256)    0           ['block12_batch_norm1[0][0]']
#
#  block12_conv2 (Conv2D)         (None, 2, 2, 1024)   263168      ['activation_68[0][0]']
#
#  block12_identity2 (Conv2D)     (None, 2, 2, 1024)   1049600     ['activation_66[0][0]']
#
#  block12_batch_norm2 (BatchNorm  (None, 2, 2, 1024)  4096        ['block12_conv2[0][0]']
#  alization)
#
#  block12_identity_bn2 (BatchNor  (None, 2, 2, 1024)  4096        ['block12_identity2[0][0]']
#  malization)
#
#  block12_add (Add)              (None, 2, 2, 1024)   0           ['block12_batch_norm2[0][0]',
#                                                                   'block12_identity_bn2[0][0]']
#
#  activation_69 (Activation)     (None, 2, 2, 1024)   0           ['block12_add[0][0]']
#
#  block13_conv0 (Conv2D)         (None, 2, 2, 256)    262400      ['activation_69[0][0]']
#
#  block13_batch_norm0 (BatchNorm  (None, 2, 2, 256)   1024        ['block13_conv0[0][0]']
#  alization)
#
#  activation_70 (Activation)     (None, 2, 2, 256)    0           ['block13_batch_norm0[0][0]']
#
#  block13_conv1 (Conv2D)         (None, 2, 2, 256)    590080      ['activation_70[0][0]']
#
#  block13_batch_norm1 (BatchNorm  (None, 2, 2, 256)   1024        ['block13_conv1[0][0]']
#  alization)
#
#  activation_71 (Activation)     (None, 2, 2, 256)    0           ['block13_batch_norm1[0][0]']
#
#  block13_conv2 (Conv2D)         (None, 2, 2, 1024)   263168      ['activation_71[0][0]']
#
#  block13_identity2 (Conv2D)     (None, 2, 2, 1024)   1049600     ['activation_69[0][0]']
#
#  block13_batch_norm2 (BatchNorm  (None, 2, 2, 1024)  4096        ['block13_conv2[0][0]']
#  alization)
#
#  block13_identity_bn2 (BatchNor  (None, 2, 2, 1024)  4096        ['block13_identity2[0][0]']
#  malization)
#
#  block13_add (Add)              (None, 2, 2, 1024)   0           ['block13_batch_norm2[0][0]',
#                                                                   'block13_identity_bn2[0][0]']
#
#  activation_72 (Activation)     (None, 2, 2, 1024)   0           ['block13_add[0][0]']
#
#  block14_conv0 (Conv2D)         (None, 1, 1, 512)    524800      ['activation_72[0][0]']
#
#  block14_batch_norm0 (BatchNorm  (None, 1, 1, 512)   2048        ['block14_conv0[0][0]']
#  alization)
#
#  activation_73 (Activation)     (None, 1, 1, 512)    0           ['block14_batch_norm0[0][0]']
#
#  block14_conv1 (Conv2D)         (None, 1, 1, 512)    2359808     ['activation_73[0][0]']
#
#  block14_batch_norm1 (BatchNorm  (None, 1, 1, 512)   2048        ['block14_conv1[0][0]']
#  alization)
#
#  activation_74 (Activation)     (None, 1, 1, 512)    0           ['block14_batch_norm1[0][0]']
#
#  block14_conv2 (Conv2D)         (None, 1, 1, 2048)   1050624     ['activation_74[0][0]']
#
#  block14_identity2 (Conv2D)     (None, 1, 1, 2048)   2099200     ['activation_72[0][0]']
#
#  block14_batch_norm2 (BatchNorm  (None, 1, 1, 2048)  8192        ['block14_conv2[0][0]']
#  alization)
#
#  block14_identity_bn2 (BatchNor  (None, 1, 1, 2048)  8192        ['block14_identity2[0][0]']
#  malization)
#
#  block14_add (Add)              (None, 1, 1, 2048)   0           ['block14_batch_norm2[0][0]',
#                                                                   'block14_identity_bn2[0][0]']
#
#  activation_75 (Activation)     (None, 1, 1, 2048)   0           ['block14_add[0][0]']
#
#  block15_conv0 (Conv2D)         (None, 1, 1, 512)    1049088     ['activation_75[0][0]']
#
#  block15_batch_norm0 (BatchNorm  (None, 1, 1, 512)   2048        ['block15_conv0[0][0]']
#  alization)
#
#  activation_76 (Activation)     (None, 1, 1, 512)    0           ['block15_batch_norm0[0][0]']
#
#  block15_conv1 (Conv2D)         (None, 1, 1, 512)    2359808     ['activation_76[0][0]']
#
#  block15_batch_norm1 (BatchNorm  (None, 1, 1, 512)   2048        ['block15_conv1[0][0]']
#  alization)
#
#  activation_77 (Activation)     (None, 1, 1, 512)    0           ['block15_batch_norm1[0][0]']
#
#  block15_conv2 (Conv2D)         (None, 1, 1, 2048)   1050624     ['activation_77[0][0]']
#
#  block15_identity2 (Conv2D)     (None, 1, 1, 2048)   4196352     ['activation_75[0][0]']
#
#  block15_batch_norm2 (BatchNorm  (None, 1, 1, 2048)  8192        ['block15_conv2[0][0]']
#  alization)
#
#  block15_identity_bn2 (BatchNor  (None, 1, 1, 2048)  8192        ['block15_identity2[0][0]']
#  malization)
#
#  block15_add (Add)              (None, 1, 1, 2048)   0           ['block15_batch_norm2[0][0]',
#                                                                   'block15_identity_bn2[0][0]']
#
#  activation_78 (Activation)     (None, 1, 1, 2048)   0           ['block15_add[0][0]']
#
#  block16_conv0 (Conv2D)         (None, 1, 1, 512)    1049088     ['activation_78[0][0]']
#
#  block16_batch_norm0 (BatchNorm  (None, 1, 1, 512)   2048        ['block16_conv0[0][0]']
#  alization)
#
#  activation_79 (Activation)     (None, 1, 1, 512)    0           ['block16_batch_norm0[0][0]']
#
#  block16_conv1 (Conv2D)         (None, 1, 1, 512)    2359808     ['activation_79[0][0]']
#
#  block16_batch_norm1 (BatchNorm  (None, 1, 1, 512)   2048        ['block16_conv1[0][0]']
#  alization)
#
#  activation_80 (Activation)     (None, 1, 1, 512)    0           ['block16_batch_norm1[0][0]']
#
#  block16_conv2 (Conv2D)         (None, 1, 1, 2048)   1050624     ['activation_80[0][0]']
#
#  block16_identity2 (Conv2D)     (None, 1, 1, 2048)   4196352     ['activation_78[0][0]']
#
#  block16_batch_norm2 (BatchNorm  (None, 1, 1, 2048)  8192        ['block16_conv2[0][0]']
#  alization)
#
#  block16_identity_bn2 (BatchNor  (None, 1, 1, 2048)  8192        ['block16_identity2[0][0]']
#  malization)
#
#  block16_add (Add)              (None, 1, 1, 2048)   0           ['block16_batch_norm2[0][0]',
#                                                                   'block16_identity_bn2[0][0]']
#
#  activation_81 (Activation)     (None, 1, 1, 2048)   0           ['block16_add[0][0]']
#
#  avg_pool (AveragePooling2D)    (None, 1, 1, 2048)   0           ['activation_81[0][0]']
#
#  Flatten (Flatten)              (None, 2048)         0           ['avg_pool[0][0]']
#
#  fc10 (Dense)                   (None, 10)           20490       ['Flatten[0][0]']
#
# ==================================================================================================
# Total params: 38,213,514
# Trainable params: 38,137,866
# Non-trainable params: 75,648
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3) 일반 네트워크(plain network) 만들기

# %% [markdown]
# ### 블록 코드 수정하기
#
# 우리는 앞에서 ResNet 모델을 구현했습니다. ResNet의 핵심 아이디어는 skip connection과 residual network기 때문에, ResNet의 효과를 보여주기 위해서는 skip connection이 없는 일반 네트워크(plain net)가 필요합니다. 위에서 ResNet 블록을 만들기 위한 함수를 그대로 활용해서 skip connection이 없는 블록을 만들 수 있도록 기능을 추가해 주세요!

# %%
def build_plain_block(x, channel=64, block_num=1, bottle_neck=False, stride=1):
    
    # 입력 레이어 x의 identity 저장 불필요
    # identity = x

    # Conv 레이어: Bottle_neck여부에 따라 3층 혹은 2층
    num_layer = 2 if bottle_neck else 1
    for cnn_num in range(num_layer + 1):
        
        # Conv
        x = keras.layers.Conv2D(
            # Bottle_neck의 경우 마지막층 채널 수 조정
            filters=channel if cnn_num != 2 else channel * 4,
            # Bottle_neck의 경우 처음과 마지막 커널 사이즈 1*1
            kernel_size= 1 if (bottle_neck and cnn_num in [0,2]) else 3,
            # 첫 레이어의 stride는 입력에 따라 조절 (Stage의 첫 레이어)
            strides=1 if cnn_num else stride,
            kernel_initializer='he_normal', padding='same',
            name=f'block{block_num}_conv{cnn_num}')(x)
        
        # Batch Norm
        x = keras.layers.BatchNormalization(
            name=f'block{block_num}_batch_norm{cnn_num}')(x)
        
        # Activation
        x = keras.layers.Activation('relu')(x)

        # 마지막 레이어는 Identity Mapping 전 활성화 함수 적용하지 않음
        # if cnn_num != num_layer:
        #    x = keras.layers.Activation('relu')(x)
        
    # Stride 혹은 Channel 수 변경 시 Identity 1x1 Conv 적용 안함.
    # stride 및 channel 동기화
#     if stride != 1 or x.shape[-1] != channel:
#         identity = keras.layers.Conv2D(filters = x.shape[-1], strides=stride,
#                                        kernel_size=1, padding='same',
#                                        kernel_initializer='he_normal',
#                                        name=f'block{block_num}_identity{cnn_num}'
#                                       )(identity)
#         identity = keras.layers.BatchNormalization(
#             name=f'block{block_num}_identity_bn{cnn_num}')(identity)
        
        
    # 마지막엔 identity mapping 안함
    # x = keras.layers.add([x, identity], name=f'block{block_num}_add')
    
    # Activation은 for문에서 이미 함.
    # x = keras.layers.Activation('relu')(x)

    return x

# %%
def build_resnet_block(x, channel=64, block_num=1, bottle_neck=False,
                       stride=1, plain=False):
    
    # 입력 레이어 x의 identity 저장
    identity = x

    # Conv 레이어: Bottle_neck여부에 따라 3층 혹은 2층
    num_layer = 2 if bottle_neck else 1
    for cnn_num in range(num_layer + 1):
        
        # Conv
        x = keras.layers.Conv2D(
            # Bottle_neck의 경우 마지막층 채널 수 조정
            filters=channel if cnn_num != 2 else channel * 4,
            # Bottle_neck의 경우 처음과 마지막 커널 사이즈 1*1
            kernel_size= 1 if (bottle_neck and cnn_num in [0,2]) else 3,
            # 첫 레이어의 stride는 입력에 따라 조절 (Stage의 첫 레이어)
            strides=1 if cnn_num else stride,
            kernel_initializer='he_normal', padding='same',
            name=f'block{block_num}_conv{cnn_num}')(x)
        
        # Batch Norm
        x = keras.layers.BatchNormalization(
            name=f'block{block_num}_batch_norm{cnn_num}')(x)

        # 마지막 레이어는 Identity Mapping 전 활성화 함수 적용하지 않음
        if cnn_num != num_layer or plain:
            x = keras.layers.Activation('relu')(x)

    if not plain:    
        # Stride 혹은 Channel 수 변경 시 Identity 1x1 Conv 적용
        # stride 및 channel 동기화
        if stride != 1 or x.shape[-1] != channel:
            identity = keras.layers.Conv2D(filters = x.shape[-1], strides=stride,
                                        kernel_size=1, padding='same',
                                        kernel_initializer='he_normal',
                                        name=f'block{block_num}_identity{cnn_num}'
                                        )(identity)
            identity = keras.layers.BatchNormalization(
                name=f'block{block_num}_identity_bn{cnn_num}')(identity)
            
            
        # 마지막엔 identity mapping
        x = keras.layers.add([x, identity], name=f'block{block_num}_add')
        
        # Activation
        x = keras.layers.Activation('relu')(x)

    return x

# %% [markdown]
# ### 전체 함수 코드 수정하기
#
# 이제 위에서 만든 블록 함수를 토대로 전체 네트워크를 만들 수 있도록 전체 네트워크 코드를 수정합시다. ResNet-50과 ResNet-34, 그리고 같은 레이어를 가지지만 skip connection이 없는 PlainNet-50과 PlainNet-34를 만들 수 있는 함수 build_plainnet()를 만들어 보세요. 이때 입력 이미지의 크기는 (224, 224, 3)으로 해주세요.

# %%
def build_plain(input_shape=(224,224,3), num_classes=10, is_50=False):
    
    input_layer = keras.layers.Input(shape=input_shape, name="Input_Layer")
    output = input_layer
    
    # Initial Conv1 (7x7, 64, stride 2)
    output = keras.layers.Conv2D(filters=64, kernel_size=7, strides=2,
                                 kernel_initializer='he_normal', padding='same',
                                 name='Initial_Conv')(output)
    output = keras.layers.BatchNormalization(name='Initial_Conv_BN')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same',
                                       name=f'Initial_Max_Pooling')(output)
    
    # Block 개수 및 채널 순서
    num_blocks_34n50 = [3, 4, 6, 3]
    channel_list = [64, 128, 256, 512]
    
    # is_50 여부에 따라 bottle_nack 옵션을 달리하여 블록을 생성    
    conv_cnt = 0
    for i, (num_cnn, channel) in enumerate(zip(num_blocks_34n50, channel_list)):
        for j in range(num_cnn):
            conv_cnt += 1
            output = build_plain_block(output, channel=channel,
                                       block_num=conv_cnt, bottle_neck=is_50,
                                       stride=2 if (i and not j) else 1)
    # 마무리
    output = keras.layers.AveragePooling2D(pool_size=(1, 1), name='avg_pool')(output)    
    output = keras.layers.Flatten(name='Flatten')(output)
    output = keras.layers.Dense(num_classes, activation='softmax',
                                name=f'fc{num_classes}')(output)

    model = keras.Model(inputs=input_layer, outputs=output,
                        name=f'PlainNet{50 if is_50 else 34}')
    
    return model

# %%
def build_resnet(input_shape=(32,32,3), num_classes=10,
                 is_50=False, plain=False):
    
    input_layer = keras.layers.Input(shape=input_shape, name="Input_Layer")
    output = input_layer
    
    # Initial Conv1 (7x7, 64, stride 2)
    output = keras.layers.Conv2D(filters=64, kernel_size=7, strides=2,
                                 kernel_initializer='he_normal', padding='same',
                                 name='Initial_Conv')(output)
    output = keras.layers.BatchNormalization(name='Initial_Conv_BN')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same',
                                       name=f'Initial_Max_Pooling')(output)
    
    # Block 개수 및 채널 순서
    num_blocks_34n50 = [3, 4, 6, 3]
    channel_list = [64, 128, 256, 512]
    
    # is_50 여부에 따라 bottle_nack 옵션을 달리하여 블록을 생성    
    conv_cnt = 0 # 블록 내 기준으로 몇 번째 Conv레이어 인지 표시할 변수
    for i, (num_cnn, channel) in enumerate(zip(num_blocks_34n50, channel_list)):
        for j in range(num_cnn):
            conv_cnt += 1
            output = build_resnet_block(output, channel=channel,
                                        block_num=conv_cnt, bottle_neck=is_50,
                                        # 채널별 가장 첫번째 블록마다 stride 변경
                                        # 단, 첫 채널은 제외
                                        stride=2 if (i and not j) else 1,
                                        plain=plain)
    # 마무리 층
    output = keras.layers.AveragePooling2D(pool_size=(1, 1), name='avg_pool')(output)    
    output = keras.layers.Flatten(name='Flatten')(output)
    output = keras.layers.Dense(num_classes, activation='softmax',
                                name=f'fc{num_classes}')(output)

    model = keras.Model(inputs=input_layer, outputs=output,
                        name=f'ResNet{50 if is_50 else 34}')
    
    return model

# %%
plain_34 = build_resnet(input_shape=(224,224,3), num_classes=2, is_50=False, plain=True)
plain_34.summary()
# Out:
# Model: "ResNet34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_Layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  Initial_Conv (Conv2D)       (None, 112, 112, 64)      9472
#
#  Initial_Conv_BN (BatchNorma  (None, 112, 112, 64)     256
#  lization)
#
#  activation_230 (Activation)  (None, 112, 112, 64)     0
#
#  Initial_Max_Pooling (MaxPoo  (None, 56, 56, 64)       0
#  ling2D)
#
#  block1_conv0 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block1_batch_norm0 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_231 (Activation)  (None, 56, 56, 64)       0
#
#  block1_conv1 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block1_batch_norm1 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_232 (Activation)  (None, 56, 56, 64)       0
#
#  block2_conv0 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block2_batch_norm0 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_233 (Activation)  (None, 56, 56, 64)       0
#
#  block2_conv1 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block2_batch_norm1 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_234 (Activation)  (None, 56, 56, 64)       0
#
#  block3_conv0 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block3_batch_norm0 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_235 (Activation)  (None, 56, 56, 64)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block3_batch_norm1 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_236 (Activation)  (None, 56, 56, 64)       0
#
#  block4_conv0 (Conv2D)       (None, 28, 28, 128)       73856
#
#  block4_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_237 (Activation)  (None, 28, 28, 128)      0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block4_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_238 (Activation)  (None, 28, 28, 128)      0
#
#  block5_conv0 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block5_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_239 (Activation)  (None, 28, 28, 128)      0
#
#  block5_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block5_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_240 (Activation)  (None, 28, 28, 128)      0
#
#  block6_conv0 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block6_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_241 (Activation)  (None, 28, 28, 128)      0
#
#  block6_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block6_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_242 (Activation)  (None, 28, 28, 128)      0
#
#  block7_conv0 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block7_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_243 (Activation)  (None, 28, 28, 128)      0
#
#  block7_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block7_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_244 (Activation)  (None, 28, 28, 128)      0
#
#  block8_conv0 (Conv2D)       (None, 14, 14, 256)       295168
#
#  block8_batch_norm0 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_245 (Activation)  (None, 14, 14, 256)      0
#
#  block8_conv1 (Conv2D)       (None, 14, 14, 256)       590080
#
#  block8_batch_norm1 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_246 (Activation)  (None, 14, 14, 256)      0
#
#  block9_conv0 (Conv2D)       (None, 14, 14, 256)       590080
#
#  block9_batch_norm0 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_247 (Activation)  (None, 14, 14, 256)      0
#
#  block9_conv1 (Conv2D)       (None, 14, 14, 256)       590080
#
#  block9_batch_norm1 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_248 (Activation)  (None, 14, 14, 256)      0
#
#  block10_conv0 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block10_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_249 (Activation)  (None, 14, 14, 256)      0
#
#  block10_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block10_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_250 (Activation)  (None, 14, 14, 256)      0
#
#  block11_conv0 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block11_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_251 (Activation)  (None, 14, 14, 256)      0
#
#  block11_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block11_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_252 (Activation)  (None, 14, 14, 256)      0
#
#  block12_conv0 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block12_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_253 (Activation)  (None, 14, 14, 256)      0
#
#  block12_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block12_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_254 (Activation)  (None, 14, 14, 256)      0
#
#  block13_conv0 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block13_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_255 (Activation)  (None, 14, 14, 256)      0
#
#  block13_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block13_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_256 (Activation)  (None, 14, 14, 256)      0
#
#  block14_conv0 (Conv2D)      (None, 7, 7, 512)         1180160
#
#  block14_batch_norm0 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_257 (Activation)  (None, 7, 7, 512)        0
#
#  block14_conv1 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block14_batch_norm1 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_258 (Activation)  (None, 7, 7, 512)        0
#
#  block15_conv0 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block15_batch_norm0 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_259 (Activation)  (None, 7, 7, 512)        0
#
#  block15_conv1 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block15_batch_norm1 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_260 (Activation)  (None, 7, 7, 512)        0
#
#  block16_conv0 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block16_batch_norm0 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_261 (Activation)  (None, 7, 7, 512)        0
#
#  block16_conv1 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block16_batch_norm1 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_262 (Activation)  (None, 7, 7, 512)        0
#
#  avg_pool (AveragePooling2D)  (None, 7, 7, 512)        0
#
#  Flatten (Flatten)           (None, 25088)             0
#
#  fc2 (Dense)                 (None, 2)                 50178
#
# =================================================================
# Total params: 21,183,874
# Trainable params: 21,168,642
# Non-trainable params: 15,232
# _________________________________________________________________

# %%
plain_34 = build_plain(input_shape=(224,224,3), num_classes=2, is_50=False)
plain_34.summary()
# Out:
# Model: "PlainNet34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_Layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  Initial_Conv (Conv2D)       (None, 112, 112, 64)      9472
#
#  Initial_Conv_BN (BatchNorma  (None, 112, 112, 64)     256
#  lization)
#
#  activation_82 (Activation)  (None, 112, 112, 64)      0
#
#  Initial_Max_Pooling (MaxPoo  (None, 56, 56, 64)       0
#  ling2D)
#
#  block1_conv0 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block1_batch_norm0 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_83 (Activation)  (None, 56, 56, 64)        0
#
#  block1_conv1 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block1_batch_norm1 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_84 (Activation)  (None, 56, 56, 64)        0
#
#  block2_conv0 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block2_batch_norm0 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_85 (Activation)  (None, 56, 56, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block2_batch_norm1 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_86 (Activation)  (None, 56, 56, 64)        0
#
#  block3_conv0 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block3_batch_norm0 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_87 (Activation)  (None, 56, 56, 64)        0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block3_batch_norm1 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_88 (Activation)  (None, 56, 56, 64)        0
#
#  block4_conv0 (Conv2D)       (None, 28, 28, 128)       73856
#
#  block4_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_89 (Activation)  (None, 28, 28, 128)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block4_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_90 (Activation)  (None, 28, 28, 128)       0
#
#  block5_conv0 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block5_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_91 (Activation)  (None, 28, 28, 128)       0
#
#  block5_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block5_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_92 (Activation)  (None, 28, 28, 128)       0
#
#  block6_conv0 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block6_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_93 (Activation)  (None, 28, 28, 128)       0
#
#  block6_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block6_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_94 (Activation)  (None, 28, 28, 128)       0
#
#  block7_conv0 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block7_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_95 (Activation)  (None, 28, 28, 128)       0
#
#  block7_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block7_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_96 (Activation)  (None, 28, 28, 128)       0
#
#  block8_conv0 (Conv2D)       (None, 14, 14, 256)       295168
#
#  block8_batch_norm0 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_97 (Activation)  (None, 14, 14, 256)       0
#
#  block8_conv1 (Conv2D)       (None, 14, 14, 256)       590080
#
#  block8_batch_norm1 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_98 (Activation)  (None, 14, 14, 256)       0
#
#  block9_conv0 (Conv2D)       (None, 14, 14, 256)       590080
#
#  block9_batch_norm0 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_99 (Activation)  (None, 14, 14, 256)       0
#
#  block9_conv1 (Conv2D)       (None, 14, 14, 256)       590080
#
#  block9_batch_norm1 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_100 (Activation)  (None, 14, 14, 256)      0
#
#  block10_conv0 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block10_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_101 (Activation)  (None, 14, 14, 256)      0
#
#  block10_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block10_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_102 (Activation)  (None, 14, 14, 256)      0
#
#  block11_conv0 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block11_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_103 (Activation)  (None, 14, 14, 256)      0
#
#  block11_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block11_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_104 (Activation)  (None, 14, 14, 256)      0
#
#  block12_conv0 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block12_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_105 (Activation)  (None, 14, 14, 256)      0
#
#  block12_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block12_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_106 (Activation)  (None, 14, 14, 256)      0
#
#  block13_conv0 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block13_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_107 (Activation)  (None, 14, 14, 256)      0
#
#  block13_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block13_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_108 (Activation)  (None, 14, 14, 256)      0
#
#  block14_conv0 (Conv2D)      (None, 7, 7, 512)         1180160
#
#  block14_batch_norm0 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_109 (Activation)  (None, 7, 7, 512)        0
#
#  block14_conv1 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block14_batch_norm1 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_110 (Activation)  (None, 7, 7, 512)        0
#
#  block15_conv0 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block15_batch_norm0 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_111 (Activation)  (None, 7, 7, 512)        0
#
#  block15_conv1 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block15_batch_norm1 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_112 (Activation)  (None, 7, 7, 512)        0
#
#  block16_conv0 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block16_batch_norm0 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_113 (Activation)  (None, 7, 7, 512)        0
#
#  block16_conv1 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block16_batch_norm1 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_114 (Activation)  (None, 7, 7, 512)        0
#
#  avg_pool (AveragePooling2D)  (None, 7, 7, 512)        0
#
#  Flatten (Flatten)           (None, 25088)             0
#
#  fc2 (Dense)                 (None, 2)                 50178
#
# =================================================================
# Total params: 21,183,874
# Trainable params: 21,168,642
# Non-trainable params: 15,232
# _________________________________________________________________

# %%
plain_50 = build_resnet(input_shape=(224,224,3), num_classes=2, is_50=True, plain=True)
plain_50.summary()
# Out:
# Model: "ResNet50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_Layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  Initial_Conv (Conv2D)       (None, 112, 112, 64)      9472
#
#  Initial_Conv_BN (BatchNorma  (None, 112, 112, 64)     256
#  lization)
#
#  activation (Activation)     (None, 112, 112, 64)      0
#
#  Initial_Max_Pooling (MaxPoo  (None, 56, 56, 64)       0
#  ling2D)
#
#  block1_conv0 (Conv2D)       (None, 56, 56, 64)        4160
#
#  block1_batch_norm0 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_1 (Activation)   (None, 56, 56, 64)        0
#
#  block1_conv1 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block1_batch_norm1 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_2 (Activation)   (None, 56, 56, 64)        0
#
#  block1_conv2 (Conv2D)       (None, 56, 56, 256)       16640
#
#  block1_batch_norm2 (BatchNo  (None, 56, 56, 256)      1024
#  rmalization)
#
#  activation_3 (Activation)   (None, 56, 56, 256)       0
#
#  block2_conv0 (Conv2D)       (None, 56, 56, 64)        16448
#
#  block2_batch_norm0 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_4 (Activation)   (None, 56, 56, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block2_batch_norm1 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_5 (Activation)   (None, 56, 56, 64)        0
#
#  block2_conv2 (Conv2D)       (None, 56, 56, 256)       16640
#
#  block2_batch_norm2 (BatchNo  (None, 56, 56, 256)      1024
#  rmalization)
#
#  activation_6 (Activation)   (None, 56, 56, 256)       0
#
#  block3_conv0 (Conv2D)       (None, 56, 56, 64)        16448
#
#  block3_batch_norm0 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_7 (Activation)   (None, 56, 56, 64)        0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block3_batch_norm1 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_8 (Activation)   (None, 56, 56, 64)        0
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       16640
#
#  block3_batch_norm2 (BatchNo  (None, 56, 56, 256)      1024
#  rmalization)
#
#  activation_9 (Activation)   (None, 56, 56, 256)       0
#
#  block4_conv0 (Conv2D)       (None, 28, 28, 128)       32896
#
#  block4_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_10 (Activation)  (None, 28, 28, 128)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block4_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_11 (Activation)  (None, 28, 28, 128)       0
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       66048
#
#  block4_batch_norm2 (BatchNo  (None, 28, 28, 512)      2048
#  rmalization)
#
#  activation_12 (Activation)  (None, 28, 28, 512)       0
#
#  block5_conv0 (Conv2D)       (None, 28, 28, 128)       65664
#
#  block5_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_13 (Activation)  (None, 28, 28, 128)       0
#
#  block5_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block5_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_14 (Activation)  (None, 28, 28, 128)       0
#
#  block5_conv2 (Conv2D)       (None, 28, 28, 512)       66048
#
#  block5_batch_norm2 (BatchNo  (None, 28, 28, 512)      2048
#  rmalization)
#
#  activation_15 (Activation)  (None, 28, 28, 512)       0
#
#  block6_conv0 (Conv2D)       (None, 28, 28, 128)       65664
#
#  block6_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_16 (Activation)  (None, 28, 28, 128)       0
#
#  block6_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block6_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_17 (Activation)  (None, 28, 28, 128)       0
#
#  block6_conv2 (Conv2D)       (None, 28, 28, 512)       66048
#
#  block6_batch_norm2 (BatchNo  (None, 28, 28, 512)      2048
#  rmalization)
#
#  activation_18 (Activation)  (None, 28, 28, 512)       0
#
#  block7_conv0 (Conv2D)       (None, 28, 28, 128)       65664
#
#  block7_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_19 (Activation)  (None, 28, 28, 128)       0
#
#  block7_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block7_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_20 (Activation)  (None, 28, 28, 128)       0
#
#  block7_conv2 (Conv2D)       (None, 28, 28, 512)       66048
#
#  block7_batch_norm2 (BatchNo  (None, 28, 28, 512)      2048
#  rmalization)
#
#  activation_21 (Activation)  (None, 28, 28, 512)       0
#
#  block8_conv0 (Conv2D)       (None, 14, 14, 256)       131328
#
#  block8_batch_norm0 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_22 (Activation)  (None, 14, 14, 256)       0
#
#  block8_conv1 (Conv2D)       (None, 14, 14, 256)       590080
#
#  block8_batch_norm1 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_23 (Activation)  (None, 14, 14, 256)       0
#
#  block8_conv2 (Conv2D)       (None, 14, 14, 1024)      263168
#
#  block8_batch_norm2 (BatchNo  (None, 14, 14, 1024)     4096
#  rmalization)
#
#  activation_24 (Activation)  (None, 14, 14, 1024)      0
#
#  block9_conv0 (Conv2D)       (None, 14, 14, 256)       262400
#
#  block9_batch_norm0 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_25 (Activation)  (None, 14, 14, 256)       0
#
#  block9_conv1 (Conv2D)       (None, 14, 14, 256)       590080
#
#  block9_batch_norm1 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_26 (Activation)  (None, 14, 14, 256)       0
#
#  block9_conv2 (Conv2D)       (None, 14, 14, 1024)      263168
#
#  block9_batch_norm2 (BatchNo  (None, 14, 14, 1024)     4096
#  rmalization)
#
#  activation_27 (Activation)  (None, 14, 14, 1024)      0
#
#  block10_conv0 (Conv2D)      (None, 14, 14, 256)       262400
#
#  block10_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_28 (Activation)  (None, 14, 14, 256)       0
#
#  block10_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block10_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_29 (Activation)  (None, 14, 14, 256)       0
#
#  block10_conv2 (Conv2D)      (None, 14, 14, 1024)      263168
#
#  block10_batch_norm2 (BatchN  (None, 14, 14, 1024)     4096
#  ormalization)
#
#  activation_30 (Activation)  (None, 14, 14, 1024)      0
#
#  block11_conv0 (Conv2D)      (None, 14, 14, 256)       262400
#
#  block11_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_31 (Activation)  (None, 14, 14, 256)       0
#
#  block11_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block11_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_32 (Activation)  (None, 14, 14, 256)       0
#
#  block11_conv2 (Conv2D)      (None, 14, 14, 1024)      263168
#
#  block11_batch_norm2 (BatchN  (None, 14, 14, 1024)     4096
#  ormalization)
#
#  activation_33 (Activation)  (None, 14, 14, 1024)      0
#
#  block12_conv0 (Conv2D)      (None, 14, 14, 256)       262400
#
#  block12_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_34 (Activation)  (None, 14, 14, 256)       0
#
#  block12_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block12_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_35 (Activation)  (None, 14, 14, 256)       0
#
#  block12_conv2 (Conv2D)      (None, 14, 14, 1024)      263168
#
#  block12_batch_norm2 (BatchN  (None, 14, 14, 1024)     4096
#  ormalization)
#
#  activation_36 (Activation)  (None, 14, 14, 1024)      0
#
#  block13_conv0 (Conv2D)      (None, 14, 14, 256)       262400
#
#  block13_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_37 (Activation)  (None, 14, 14, 256)       0
#
#  block13_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block13_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_38 (Activation)  (None, 14, 14, 256)       0
#
#  block13_conv2 (Conv2D)      (None, 14, 14, 1024)      263168
#
#  block13_batch_norm2 (BatchN  (None, 14, 14, 1024)     4096
#  ormalization)
#
#  activation_39 (Activation)  (None, 14, 14, 1024)      0
#
#  block14_conv0 (Conv2D)      (None, 7, 7, 512)         524800
#
#  block14_batch_norm0 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_40 (Activation)  (None, 7, 7, 512)         0
#
#  block14_conv1 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block14_batch_norm1 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_41 (Activation)  (None, 7, 7, 512)         0
#
#  block14_conv2 (Conv2D)      (None, 7, 7, 2048)        1050624
#
#  block14_batch_norm2 (BatchN  (None, 7, 7, 2048)       8192
#  ormalization)
#
#  activation_42 (Activation)  (None, 7, 7, 2048)        0
#
#  block15_conv0 (Conv2D)      (None, 7, 7, 512)         1049088
#
#  block15_batch_norm0 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_43 (Activation)  (None, 7, 7, 512)         0
#
#  block15_conv1 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block15_batch_norm1 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_44 (Activation)  (None, 7, 7, 512)         0
#
#  block15_conv2 (Conv2D)      (None, 7, 7, 2048)        1050624
#
#  block15_batch_norm2 (BatchN  (None, 7, 7, 2048)       8192
#  ormalization)
#
#  activation_45 (Activation)  (None, 7, 7, 2048)        0
#
#  block16_conv0 (Conv2D)      (None, 7, 7, 512)         1049088
#
#  block16_batch_norm0 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_46 (Activation)  (None, 7, 7, 512)         0
#
#  block16_conv1 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block16_batch_norm1 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_47 (Activation)  (None, 7, 7, 512)         0
#
#  block16_conv2 (Conv2D)      (None, 7, 7, 2048)        1050624
#
#  block16_batch_norm2 (BatchN  (None, 7, 7, 2048)       8192
#  ormalization)
#
#  activation_48 (Activation)  (None, 7, 7, 2048)        0
#
#  avg_pool (AveragePooling2D)  (None, 7, 7, 2048)       0
#
#  Flatten (Flatten)           (None, 100352)            0
#
#  fc2 (Dense)                 (None, 2)                 200706
#
# =================================================================
# Total params: 21,000,322
# Trainable params: 20,954,882
# Non-trainable params: 45,440
# _________________________________________________________________

# %%
plain_50 = build_plain(input_shape=(224,224,3), num_classes=2, is_50=True)
plain_50.summary()
# Out:
# Model: "PlainNet50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_Layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  Initial_Conv (Conv2D)       (None, 112, 112, 64)      9472
#
#  Initial_Conv_BN (BatchNorma  (None, 112, 112, 64)     256
#  lization)
#
#  activation_115 (Activation)  (None, 112, 112, 64)     0
#
#  Initial_Max_Pooling (MaxPoo  (None, 56, 56, 64)       0
#  ling2D)
#
#  block1_conv0 (Conv2D)       (None, 56, 56, 64)        4160
#
#  block1_batch_norm0 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_116 (Activation)  (None, 56, 56, 64)       0
#
#  block1_conv1 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block1_batch_norm1 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_117 (Activation)  (None, 56, 56, 64)       0
#
#  block1_conv2 (Conv2D)       (None, 56, 56, 256)       16640
#
#  block1_batch_norm2 (BatchNo  (None, 56, 56, 256)      1024
#  rmalization)
#
#  activation_118 (Activation)  (None, 56, 56, 256)      0
#
#  block2_conv0 (Conv2D)       (None, 56, 56, 64)        16448
#
#  block2_batch_norm0 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_119 (Activation)  (None, 56, 56, 64)       0
#
#  block2_conv1 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block2_batch_norm1 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_120 (Activation)  (None, 56, 56, 64)       0
#
#  block2_conv2 (Conv2D)       (None, 56, 56, 256)       16640
#
#  block2_batch_norm2 (BatchNo  (None, 56, 56, 256)      1024
#  rmalization)
#
#  activation_121 (Activation)  (None, 56, 56, 256)      0
#
#  block3_conv0 (Conv2D)       (None, 56, 56, 64)        16448
#
#  block3_batch_norm0 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_122 (Activation)  (None, 56, 56, 64)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 64)        36928
#
#  block3_batch_norm1 (BatchNo  (None, 56, 56, 64)       256
#  rmalization)
#
#  activation_123 (Activation)  (None, 56, 56, 64)       0
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       16640
#
#  block3_batch_norm2 (BatchNo  (None, 56, 56, 256)      1024
#  rmalization)
#
#  activation_124 (Activation)  (None, 56, 56, 256)      0
#
#  block4_conv0 (Conv2D)       (None, 28, 28, 128)       32896
#
#  block4_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_125 (Activation)  (None, 28, 28, 128)      0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block4_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_126 (Activation)  (None, 28, 28, 128)      0
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       66048
#
#  block4_batch_norm2 (BatchNo  (None, 28, 28, 512)      2048
#  rmalization)
#
#  activation_127 (Activation)  (None, 28, 28, 512)      0
#
#  block5_conv0 (Conv2D)       (None, 28, 28, 128)       65664
#
#  block5_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_128 (Activation)  (None, 28, 28, 128)      0
#
#  block5_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block5_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_129 (Activation)  (None, 28, 28, 128)      0
#
#  block5_conv2 (Conv2D)       (None, 28, 28, 512)       66048
#
#  block5_batch_norm2 (BatchNo  (None, 28, 28, 512)      2048
#  rmalization)
#
#  activation_130 (Activation)  (None, 28, 28, 512)      0
#
#  block6_conv0 (Conv2D)       (None, 28, 28, 128)       65664
#
#  block6_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_131 (Activation)  (None, 28, 28, 128)      0
#
#  block6_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block6_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_132 (Activation)  (None, 28, 28, 128)      0
#
#  block6_conv2 (Conv2D)       (None, 28, 28, 512)       66048
#
#  block6_batch_norm2 (BatchNo  (None, 28, 28, 512)      2048
#  rmalization)
#
#  activation_133 (Activation)  (None, 28, 28, 512)      0
#
#  block7_conv0 (Conv2D)       (None, 28, 28, 128)       65664
#
#  block7_batch_norm0 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_134 (Activation)  (None, 28, 28, 128)      0
#
#  block7_conv1 (Conv2D)       (None, 28, 28, 128)       147584
#
#  block7_batch_norm1 (BatchNo  (None, 28, 28, 128)      512
#  rmalization)
#
#  activation_135 (Activation)  (None, 28, 28, 128)      0
#
#  block7_conv2 (Conv2D)       (None, 28, 28, 512)       66048
#
#  block7_batch_norm2 (BatchNo  (None, 28, 28, 512)      2048
#  rmalization)
#
#  activation_136 (Activation)  (None, 28, 28, 512)      0
#
#  block8_conv0 (Conv2D)       (None, 14, 14, 256)       131328
#
#  block8_batch_norm0 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_137 (Activation)  (None, 14, 14, 256)      0
#
#  block8_conv1 (Conv2D)       (None, 14, 14, 256)       590080
#
#  block8_batch_norm1 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_138 (Activation)  (None, 14, 14, 256)      0
#
#  block8_conv2 (Conv2D)       (None, 14, 14, 1024)      263168
#
#  block8_batch_norm2 (BatchNo  (None, 14, 14, 1024)     4096
#  rmalization)
#
#  activation_139 (Activation)  (None, 14, 14, 1024)     0
#
#  block9_conv0 (Conv2D)       (None, 14, 14, 256)       262400
#
#  block9_batch_norm0 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_140 (Activation)  (None, 14, 14, 256)      0
#
#  block9_conv1 (Conv2D)       (None, 14, 14, 256)       590080
#
#  block9_batch_norm1 (BatchNo  (None, 14, 14, 256)      1024
#  rmalization)
#
#  activation_141 (Activation)  (None, 14, 14, 256)      0
#
#  block9_conv2 (Conv2D)       (None, 14, 14, 1024)      263168
#
#  block9_batch_norm2 (BatchNo  (None, 14, 14, 1024)     4096
#  rmalization)
#
#  activation_142 (Activation)  (None, 14, 14, 1024)     0
#
#  block10_conv0 (Conv2D)      (None, 14, 14, 256)       262400
#
#  block10_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_143 (Activation)  (None, 14, 14, 256)      0
#
#  block10_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block10_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_144 (Activation)  (None, 14, 14, 256)      0
#
#  block10_conv2 (Conv2D)      (None, 14, 14, 1024)      263168
#
#  block10_batch_norm2 (BatchN  (None, 14, 14, 1024)     4096
#  ormalization)
#
#  activation_145 (Activation)  (None, 14, 14, 1024)     0
#
#  block11_conv0 (Conv2D)      (None, 14, 14, 256)       262400
#
#  block11_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_146 (Activation)  (None, 14, 14, 256)      0
#
#  block11_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block11_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_147 (Activation)  (None, 14, 14, 256)      0
#
#  block11_conv2 (Conv2D)      (None, 14, 14, 1024)      263168
#
#  block11_batch_norm2 (BatchN  (None, 14, 14, 1024)     4096
#  ormalization)
#
#  activation_148 (Activation)  (None, 14, 14, 1024)     0
#
#  block12_conv0 (Conv2D)      (None, 14, 14, 256)       262400
#
#  block12_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_149 (Activation)  (None, 14, 14, 256)      0
#
#  block12_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block12_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_150 (Activation)  (None, 14, 14, 256)      0
#
#  block12_conv2 (Conv2D)      (None, 14, 14, 1024)      263168
#
#  block12_batch_norm2 (BatchN  (None, 14, 14, 1024)     4096
#  ormalization)
#
#  activation_151 (Activation)  (None, 14, 14, 1024)     0
#
#  block13_conv0 (Conv2D)      (None, 14, 14, 256)       262400
#
#  block13_batch_norm0 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_152 (Activation)  (None, 14, 14, 256)      0
#
#  block13_conv1 (Conv2D)      (None, 14, 14, 256)       590080
#
#  block13_batch_norm1 (BatchN  (None, 14, 14, 256)      1024
#  ormalization)
#
#  activation_153 (Activation)  (None, 14, 14, 256)      0
#
#  block13_conv2 (Conv2D)      (None, 14, 14, 1024)      263168
#
#  block13_batch_norm2 (BatchN  (None, 14, 14, 1024)     4096
#  ormalization)
#
#  activation_154 (Activation)  (None, 14, 14, 1024)     0
#
#  block14_conv0 (Conv2D)      (None, 7, 7, 512)         524800
#
#  block14_batch_norm0 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_155 (Activation)  (None, 7, 7, 512)        0
#
#  block14_conv1 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block14_batch_norm1 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_156 (Activation)  (None, 7, 7, 512)        0
#
#  block14_conv2 (Conv2D)      (None, 7, 7, 2048)        1050624
#
#  block14_batch_norm2 (BatchN  (None, 7, 7, 2048)       8192
#  ormalization)
#
#  activation_157 (Activation)  (None, 7, 7, 2048)       0
#
#  block15_conv0 (Conv2D)      (None, 7, 7, 512)         1049088
#
#  block15_batch_norm0 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_158 (Activation)  (None, 7, 7, 512)        0
#
#  block15_conv1 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block15_batch_norm1 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_159 (Activation)  (None, 7, 7, 512)        0
#
#  block15_conv2 (Conv2D)      (None, 7, 7, 2048)        1050624
#
#  block15_batch_norm2 (BatchN  (None, 7, 7, 2048)       8192
#  ormalization)
#
#  activation_160 (Activation)  (None, 7, 7, 2048)       0
#
#  block16_conv0 (Conv2D)      (None, 7, 7, 512)         1049088
#
#  block16_batch_norm0 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_161 (Activation)  (None, 7, 7, 512)        0
#
#  block16_conv1 (Conv2D)      (None, 7, 7, 512)         2359808
#
#  block16_batch_norm1 (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  activation_162 (Activation)  (None, 7, 7, 512)        0
#
#  block16_conv2 (Conv2D)      (None, 7, 7, 2048)        1050624
#
#  block16_batch_norm2 (BatchN  (None, 7, 7, 2048)       8192
#  ormalization)
#
#  activation_163 (Activation)  (None, 7, 7, 2048)       0
#
#  avg_pool (AveragePooling2D)  (None, 7, 7, 2048)       0
#
#  Flatten (Flatten)           (None, 100352)            0
#
#  fc2 (Dense)                 (None, 2)                 200706
#
# =================================================================
# Total params: 21,000,322
# Trainable params: 20,954,882
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ## 4) ResNet-50 vs Plain-50 또는 ResNet-34 vs Plain-34

# %% [markdown]
# - Ablation Study
#
# 이제 VGG-16, 19 예제와 같이 ResNet-50 vs Plain-50 또는 ResNet-34 vs Plain-34에 대해서 학습을 진행해 봅니다. 그리고 결과를 비교해 봅시다! ResNet은 많은 레이어와 Pooling을 거치므로 CIFAR-10에서는 오버피팅(overfitting)으로 잘 동작하지 않을 수 있습니다. 레이어가 많고 학습해야 할 변수(parameter)가 많은 데 비해, 데이터 수가 많지 않기 때문이지요. 224x224 픽셀 크기의 데이터셋을 찾아서 실험해 보도록 합시다. 학습은 끝까지 시키기엔 시간이 없으니 확인을 위한 정도의 epoch로 설정해 주세요.
#
# 어떤 데이터셋을 사용하셔도 무방하지만, 얼른 떠오르는 것이 없다면 tensorflow-datasets에서 제공하는 cats_vs_dogs 데이터셋을 추천합니다. 아마 이 데이터셋도 다루어 보신 적이 있을 것입니다. Tensorflow에서 제공하는 데이터셋이므로 오늘 VGG 학습에 사용했던 CIFAR-10을 로딩하는 것과 같은 방법으로 활용하실 수 있습니다.

# %% [markdown]
# ### DataSet 준비

# %% [markdown]
# - 데이터셋 링크 변수 수정

# %%
setattr(tfds.image_classification.cats_vs_dogs,'_URL',
        "https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip")

# %% [markdown]
# - Data Load 및 분리

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    shuffle_files=False,
    with_info=True,
)

# %% [markdown]
# - 데이터 확인

# %%
# 데이터 개수 확인
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(18610, shape=(), dtype=int64)
# tf.Tensor(4652, shape=(), dtype=int64)

# %%
# feature 정보 확인
print(ds_info.features)
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=uint8),
#     'image/filename': Text(shape=(), dtype=string),
#     'label': ClassLabel(shape=(), dtype=int64, num_classes=2),
# })

# %%
ds_info.features["label"].num_classes
# Out:
# 2

# %%
ds_info.features["label"].names
# Out:
# ['cat', 'dog']

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %%
fig = tfds.show_examples(ds_test, ds_info)

# %%
def get_num_class(dataset):
    # 클래스별 카운트를 저장할 딕셔너리 초기화
    class_counts = {0: 0, 1: 0}

    # 데이터셋 순회하며 레이블 카운트
    for image, label in dataset:
        class_counts[label.numpy()] += 1
    
    return class_counts

# %% [markdown]
# - 학습용 데이터 기준, 고양이 9378, 개 9232

# %%
get_num_class(ds_train)
# Out:
# {0: 9378, 1: 9232}

# %% [markdown]
# - 검증용 데이터 기준, 고양이 2280, 개 2372

# %%
get_num_class(ds_test)
# Out:
# {0: 2280, 1: 2372}

# %% [markdown]
# - 이미지 사이즈가 다르니 같은 사이즈로 맞춰줄 필요가 있음.

# %%
cnt = 0

for img, label in ds_test:
    print(img.shape)
    cnt += 1
    if cnt == 3:
        break
# Out:
# (176, 168, 3)
# (360, 400, 3)
# (336, 500, 3)

# %% [markdown]
# - 데이터 전처리 함수 (Resize, Normalization)

# %%
def normalize_and_resize_img(image, label, size=(224, 224)):
    """Normalizes images: `uint8` -> `float32`."""
    image = tf.image.resize(image, size)
    return tf.cast(image, tf.float32) / 255., label
    
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
# BATCH_SIZE = 256
# EPOCH = 15

# %%
BATCH_SIZE = 125
EPOCH = 15

# %%
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %% [markdown]
# ### 학습

# %% [markdown]
# - 데이터셋에 맞게 모델 빌드

# %%
resnet_34 = build_resnet(input_shape=(224,224,3), num_classes=2, is_50=False)

# %%
resnet_34.compile(loss='sparse_categorical_crossentropy',
                  optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
                  metrics=['accuracy'])

history_34 = resnet_34.fit(ds_train,
                           epochs=EPOCH, validation_data=ds_test,verbose=1,
                           use_multiprocessing=True)
# Out:
# Epoch 1/15
# c:\Users\AIDL_\anaconda3\envs\env01\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 73/73 [==============================] - 49s 534ms/step - loss: 1.1442 - accuracy: 0.5363 - val_loss: 4.0145 - val_accuracy: 0.5168
# Epoch 2/15
# 73/73 [==============================] - 37s 502ms/step - loss: 0.9774 - accuracy: 0.5843 - val_loss: 1.1179 - val_accuracy: 0.5107
# Epoch 3/15
# 73/73 [==============================] - 37s 506ms/step - loss: 0.8153 - accuracy: 0.6301 - val_loss: 0.7633 - val_accuracy: 0.5853
# Epoch 4/15
# 73/73 [==============================] - 37s 504ms/step - loss: 0.6872 - accuracy: 0.6745 - val_loss: 1.1174 - val_accuracy: 0.5234
# Epoch 5/15
# 73/73 [==============================] - 37s 504ms/step - loss: 0.5458 - accuracy: 0.7295 - val_loss: 0.7273 - val_accuracy: 0.6240
# Epoch 6/15
# 73/73 [==============================] - 37s 506ms/step - loss: 0.4357 - accuracy: 0.7778 - val_loss: 0.9555 - val_accuracy: 0.5911
# Epoch 7/15
# 73/73 [==============================] - 37s 505ms/step - loss: 0.3304 - accuracy: 0.8396 - val_loss: 0.7790 - val_accuracy: 0.6376
# Epoch 8/15
# 73/73 [==============================] - 37s 504ms/step - loss: 0.2441 - accuracy: 0.8894 - val_loss: 0.9065 - val_accuracy: 0.6189
# Epoch 9/15
# 73/73 [==============================] - 37s 504ms/step - loss: 0.1696 - accuracy: 0.9408 - val_loss: 0.8083 - val_accuracy: 0.6457
# Epoch 10/15
# 73/73 [==============================] - 37s 504ms/step - loss: 0.1133 - accuracy: 0.9702 - val_loss: 0.9778 - val_accuracy: 0.6221
# Epoch 11/15
# 73/73 [==============================] - 37s 505ms/step - loss: 0.0710 - accuracy: 0.9890 - val_loss: 0.8806 - val_accuracy: 0.6503
# Epoch 12/15
# 73/73 [==============================] - 37s 505ms/step - loss: 0.0360 - accuracy: 0.9989 - val_loss: 0.9481 - val_accuracy: 0.6432
# Epoch 13/15
# 73/73 [==============================] - 37s 509ms/step - loss: 0.0186 - accuracy: 0.9998 - val_loss: 0.9502 - val_accuracy: 0.6595
# Epoch 14/15
# 73/73 [==============================] - 37s 507ms/step - loss: 0.0081 - accuracy: 0.9999 - val_loss: 0.9466 - val_accuracy: 0.6586
# Epoch 15/15
# 73/73 [==============================] - 37s 505ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.9704 - val_accuracy: 0.6550

# %%
resnet_34_005 = build_resnet(input_shape=(224,224,3), num_classes=2, is_50=False)

# %%
resnet_34_005.compile(loss='sparse_categorical_crossentropy',
                  optimizer=tf.keras.optimizers.SGD(learning_rate=0.005, clipnorm=1.),
                  metrics=['accuracy'])

resnet_34_005 = resnet_34_005.fit(ds_train,
                           epochs=EPOCH, validation_data=ds_test,verbose=1,
                           use_multiprocessing=True)
# Out:
# Epoch 1/15
# 73/73 [==============================] - 40s 508ms/step - loss: 1.0045 - accuracy: 0.5422 - val_loss: 1.2032 - val_accuracy: 0.4841
# Epoch 2/15
# 73/73 [==============================] - 37s 506ms/step - loss: 0.7270 - accuracy: 0.6433 - val_loss: 0.8039 - val_accuracy: 0.5471
# Epoch 3/15
# 73/73 [==============================] - 37s 506ms/step - loss: 0.4855 - accuracy: 0.7580 - val_loss: 0.9384 - val_accuracy: 0.5286
# Epoch 4/15
# 73/73 [==============================] - 37s 506ms/step - loss: 0.3075 - accuracy: 0.8677 - val_loss: 0.8056 - val_accuracy: 0.5692
# Epoch 5/15
# 73/73 [==============================] - 37s 505ms/step - loss: 0.2066 - accuracy: 0.9366 - val_loss: 0.9561 - val_accuracy: 0.5673
# Epoch 6/15
# 73/73 [==============================] - 37s 505ms/step - loss: 0.1334 - accuracy: 0.9786 - val_loss: 0.8328 - val_accuracy: 0.5974
# Epoch 7/15
# 73/73 [==============================] - 37s 505ms/step - loss: 0.0902 - accuracy: 0.9937 - val_loss: 0.9315 - val_accuracy: 0.5888
# Epoch 8/15
# 73/73 [==============================] - 37s 506ms/step - loss: 0.0562 - accuracy: 0.9990 - val_loss: 0.8592 - val_accuracy: 0.6077
# Epoch 9/15
# 73/73 [==============================] - 37s 506ms/step - loss: 0.0358 - accuracy: 1.0000 - val_loss: 0.9229 - val_accuracy: 0.6053
# Epoch 10/15
# 73/73 [==============================] - 37s 505ms/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.8954 - val_accuracy: 0.6116
# Epoch 11/15
# 73/73 [==============================] - 37s 505ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.9212 - val_accuracy: 0.6165
# Epoch 12/15
# 73/73 [==============================] - 37s 505ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.9407 - val_accuracy: 0.6176
# Epoch 13/15
# 73/73 [==============================] - 37s 506ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.9561 - val_accuracy: 0.6154
# Epoch 14/15
# 73/73 [==============================] - 37s 506ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.9544 - val_accuracy: 0.6161
# Epoch 15/15
# 73/73 [==============================] - 37s 505ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.9745 - val_accuracy: 0.6159

# %%
plain_34.compile(loss='sparse_categorical_crossentropy',
                  optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, clipnorm=1.),
                  metrics=['accuracy'])

history_p34 = plain_34.fit(ds_train, epochs=EPOCH, validation_data=ds_test,verbose=1,
                           use_multiprocessing=True)
# Out:
# Epoch 1/15
# 73/73 [==============================] - 38s 483ms/step - loss: 0.7982 - accuracy: 0.5166 - val_loss: 0.7178 - val_accuracy: 0.4897
# Epoch 2/15
# 73/73 [==============================] - 35s 484ms/step - loss: 0.7775 - accuracy: 0.5316 - val_loss: 0.7824 - val_accuracy: 0.4893
# Epoch 3/15
# 73/73 [==============================] - 36s 487ms/step - loss: 0.7557 - accuracy: 0.5326 - val_loss: 0.7957 - val_accuracy: 0.4899
# Epoch 4/15
# 73/73 [==============================] - 35s 485ms/step - loss: 0.7416 - accuracy: 0.5441 - val_loss: 0.7229 - val_accuracy: 0.5009
# Epoch 5/15
# 73/73 [==============================] - 35s 484ms/step - loss: 0.7290 - accuracy: 0.5545 - val_loss: 0.7147 - val_accuracy: 0.5333
# Epoch 6/15
# 73/73 [==============================] - 35s 484ms/step - loss: 0.7268 - accuracy: 0.5573 - val_loss: 0.7422 - val_accuracy: 0.5729
# Epoch 7/15
# 73/73 [==============================] - 35s 482ms/step - loss: 0.7112 - accuracy: 0.5672 - val_loss: 0.8133 - val_accuracy: 0.5353
# Epoch 8/15
# 73/73 [==============================] - 35s 483ms/step - loss: 0.7121 - accuracy: 0.5684 - val_loss: 0.7477 - val_accuracy: 0.5471
# Epoch 9/15
# 73/73 [==============================] - 35s 484ms/step - loss: 0.7114 - accuracy: 0.5643 - val_loss: 0.9110 - val_accuracy: 0.5411
# Epoch 10/15
# 73/73 [==============================] - 35s 485ms/step - loss: 0.7033 - accuracy: 0.5686 - val_loss: 0.7834 - val_accuracy: 0.5299
# Epoch 11/15
# 73/73 [==============================] - 36s 487ms/step - loss: 0.6998 - accuracy: 0.5737 - val_loss: 0.7439 - val_accuracy: 0.5368
# Epoch 12/15
# 73/73 [==============================] - 36s 486ms/step - loss: 0.7022 - accuracy: 0.5733 - val_loss: 1.1169 - val_accuracy: 0.5361
# Epoch 13/15
# 73/73 [==============================] - 36s 486ms/step - loss: 0.6924 - accuracy: 0.5821 - val_loss: 0.8567 - val_accuracy: 0.5267
# Epoch 14/15
# 73/73 [==============================] - 35s 484ms/step - loss: 0.6964 - accuracy: 0.5821 - val_loss: 0.7114 - val_accuracy: 0.5808
# Epoch 15/15
# 73/73 [==============================] - 36s 486ms/step - loss: 0.6899 - accuracy: 0.5890 - val_loss: 0.8188 - val_accuracy: 0.5344

# %%
def visualize_training(resnet_history, plain_history):
    plt.figure(figsize=(15,15))

    plt.subplot(221)
    plt.plot(resnet_history.history['loss'], 'r')
    plt.plot(plain_history.history['loss'], 'b')
    plt.title('Training Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['ResNet34', 'PlainNet34'], loc='upper right')

    plt.subplot(222)
    plt.plot(resnet_history.history['accuracy'], 'r')
    plt.plot(plain_history.history['accuracy'], 'b')
    plt.title('Training Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['ResNet34', 'PlainNet34'], loc='upper left')

    plt.subplot(223)
    plt.plot(resnet_history.history['val_loss'], 'r')
    plt.plot(plain_history.history['val_loss'], 'b')
    plt.title('Validation Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['ResNet34', 'PlainNet34'], loc='upper right')

    plt.subplot(224)
    plt.plot(resnet_history.history['val_accuracy'], 'r')
    plt.plot(plain_history.history['val_accuracy'], 'b')
    plt.title('Validation Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['ResNet34', 'PlainNet34'], loc='upper left')

    plt.show()

# %%
visualize_training(history_34, history_p34)

# %%
resnet_50 = build_resnet(input_shape=(224,224, 3), num_classes=2, is_50=True)

# %%
resnet_50.compile(loss='sparse_categorical_crossentropy',
                  optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, clipnorm=1.),
                  metrics=['accuracy'])

history_50 = resnet_50.fit(ds_train,
                           epochs=EPOCH, validation_data=ds_test,verbose=1,
                           use_multiprocessing=True)
# Out:
# Epoch 1/15
# 149/149 [==============================] - 85s 527ms/step - loss: 0.9421 - accuracy: 0.5202 - val_loss: 0.7901 - val_accuracy: 0.4880
# Epoch 2/15
# 149/149 [==============================] - 77s 518ms/step - loss: 0.8967 - accuracy: 0.5331 - val_loss: 0.7685 - val_accuracy: 0.5071
# Epoch 3/15
# 149/149 [==============================] - 78s 520ms/step - loss: 0.8547 - accuracy: 0.5496 - val_loss: 0.9147 - val_accuracy: 0.5325
# Epoch 4/15
# 149/149 [==============================] - 79s 531ms/step - loss: 0.8688 - accuracy: 0.5437 - val_loss: 1.0392 - val_accuracy: 0.5400
# Epoch 5/15
# 149/149 [==============================] - 79s 529ms/step - loss: 0.8486 - accuracy: 0.5519 - val_loss: 0.9207 - val_accuracy: 0.5408
# Epoch 6/15
# 149/149 [==============================] - 76s 513ms/step - loss: 0.8138 - accuracy: 0.5541 - val_loss: 1.0214 - val_accuracy: 0.5550
# Epoch 7/15
# 149/149 [==============================] - 76s 513ms/step - loss: 0.8136 - accuracy: 0.5583 - val_loss: 1.4448 - val_accuracy: 0.5482
# Epoch 8/15
# 149/149 [==============================] - 77s 515ms/step - loss: 0.8001 - accuracy: 0.5657 - val_loss: 1.1364 - val_accuracy: 0.5647
# Epoch 9/15
# 149/149 [==============================] - 77s 516ms/step - loss: 0.7825 - accuracy: 0.5728 - val_loss: 1.2714 - val_accuracy: 0.5643
# Epoch 10/15
# 149/149 [==============================] - 77s 516ms/step - loss: 0.7675 - accuracy: 0.5788 - val_loss: 1.1389 - val_accuracy: 0.5851
# Epoch 11/15
# 149/149 [==============================] - 77s 516ms/step - loss: 0.7603 - accuracy: 0.5832 - val_loss: 0.8653 - val_accuracy: 0.6032
# Epoch 12/15
# 149/149 [==============================] - 77s 516ms/step - loss: 0.7577 - accuracy: 0.5879 - val_loss: 0.8520 - val_accuracy: 0.5911
# Epoch 13/15
# 149/149 [==============================] - 77s 515ms/step - loss: 0.7416 - accuracy: 0.5876 - val_loss: 1.2019 - val_accuracy: 0.5626
# Epoch 14/15
# 149/149 [==============================] - 77s 515ms/step - loss: 0.7325 - accuracy: 0.5962 - val_loss: 0.8767 - val_accuracy: 0.5632
# Epoch 15/15
# 149/149 [==============================] - 77s 516ms/step - loss: 0.7198 - accuracy: 0.5941 - val_loss: 0.8577 - val_accuracy: 0.5886

# %%
plain_50.compile(loss='sparse_categorical_crossentropy',
                  optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, clipnorm=1.),
                  metrics=['accuracy'])

history_p50 = plain_50.fit(ds_train, epochs=EPOCH, validation_data=ds_test,verbose=1,
                           use_multiprocessing=True)
# Out:
# Epoch 1/15
# 149/149 [==============================] - 56s 329ms/step - loss: 0.8115 - accuracy: 0.5217 - val_loss: 0.7220 - val_accuracy: 0.4910
# Epoch 2/15
# 149/149 [==============================] - 48s 322ms/step - loss: 0.7957 - accuracy: 0.5328 - val_loss: 0.7152 - val_accuracy: 0.5058
# Epoch 3/15
# 149/149 [==============================] - 48s 323ms/step - loss: 0.7858 - accuracy: 0.5419 - val_loss: 1.2062 - val_accuracy: 0.5196
# Epoch 4/15
# 149/149 [==============================] - 48s 323ms/step - loss: 0.7942 - accuracy: 0.5331 - val_loss: 0.8956 - val_accuracy: 0.5217
# Epoch 5/15
# 149/149 [==============================] - 48s 322ms/step - loss: 0.7893 - accuracy: 0.5312 - val_loss: 1.5010 - val_accuracy: 0.5269
# Epoch 6/15
# 149/149 [==============================] - 48s 322ms/step - loss: 0.7763 - accuracy: 0.5416 - val_loss: 0.7922 - val_accuracy: 0.5529
# Epoch 7/15
# 149/149 [==============================] - 48s 322ms/step - loss: 0.7782 - accuracy: 0.5382 - val_loss: 0.7354 - val_accuracy: 0.5531
# Epoch 8/15
# 149/149 [==============================] - 48s 322ms/step - loss: 0.7790 - accuracy: 0.5430 - val_loss: 0.9728 - val_accuracy: 0.5623
# Epoch 9/15
# 149/149 [==============================] - 48s 323ms/step - loss: 0.7712 - accuracy: 0.5466 - val_loss: 0.8847 - val_accuracy: 0.5666
# Epoch 10/15
# 149/149 [==============================] - 48s 322ms/step - loss: 0.7681 - accuracy: 0.5512 - val_loss: 0.8231 - val_accuracy: 0.5535
# Epoch 11/15
# 149/149 [==============================] - 48s 322ms/step - loss: 0.7715 - accuracy: 0.5445 - val_loss: 0.7769 - val_accuracy: 0.5542
# Epoch 12/15
# 149/149 [==============================] - 48s 322ms/step - loss: 0.7633 - accuracy: 0.5557 - val_loss: 0.7077 - val_accuracy: 0.5673
# Epoch 13/15
# 149/149 [==============================] - 48s 322ms/step - loss: 0.7659 - accuracy: 0.5514 - val_loss: 0.8300 - val_accuracy: 0.5537
# Epoch 14/15
# 149/149 [==============================] - 48s 321ms/step - loss: 0.7654 - accuracy: 0.5494 - val_loss: 1.1588 - val_accuracy: 0.5593
# Epoch 15/15
# 149/149 [==============================] - 48s 321ms/step - loss: 0.7673 - accuracy: 0.5510 - val_loss: 1.2067 - val_accuracy: 0.5572

# %%
visualize_training(history_50, history_p50)

# %% [markdown]
# ![image.png](attachment:image.png)
